# %%
# Mount to Google drive
from google.colab import drive
drive.mount('/content/drive/')

# Navigate to necessary folder
# %cd '/content/drive/My Drive/Data 255 Spring 2024/Google Colab/Homework5'
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/Data 255 Spring 2024/Google Colab/Homework5

# %% [markdown]
# **Step1. Load the Fashion MNIST dataset and replace the original dataset used in the demo.**

# %%
# Import necessary libraries

import torch
import torchvision
import torch.nn as nn
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
import torchvision.utils as vutils
# Predefined fuction to save images
from torchvision.utils import save_image
from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline
import os
from IPython.display import Image

# %%
# Device configuration,GPU or the CPU is checked in this block

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
#Load the dataset, train dataset, and transform to tensor, data preprocessing task

mnist = FashionMNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %%
#Viewing the data

img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %%
# Viewing the images we would like to de normalize it
# Currently the image is normalized to [-,1,1[] and we convert
# back to [0,1[] to show the image. Tensor x on adding one shifts from
# [-1,1] to [0,2] and divding by 2 give [0,1]. Clamp makes sure
# values outside of [0,1] are set to 0 or 1

def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
# Set variables

# Size of each batch
batch_size = 100
# image size 28*28
image_size = 784

hidden_size = 256
# Dimentionality of the latent space, larger latent space
# captures more intricate patterns, but also requires more resources
latent_size = 64

# %%
#To ensure that the data is loaded in batches during training we are using a DataLoader.

data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
# Plot some training images
import numpy as np

real_batch = next(iter(data_loader))
plt.figure(figsize=(5, 5))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
# Create a directory to save the real image

sample_dir = 'samples_chk_10E'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
# Save real image

for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

# Show the real image - which is the first batch of 100 images
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# **Step2. Train the GAN model to produce images in this new domain.**

# %% [markdown]
# Define the **Discriminator**

# %%
#Define a pretty simple Disriminator network which has:
# 1. Linear layer which takes in an input of image_size as 784 and hidden size 256
# 2. The output of the linear layer is passed through a ReLU activation function
# 3. The result of the activation function is then passed through a Linear layer which takes in 256 input and produces 256 outputs
# 4. This result is again passed through a leaky relu layer.
# 5. Finally the output is passed through a Linear layer and the result is passed through the sigmoid function.

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# Define the **Generator**

# %%
#Define a pretty simple Generator network which has:
# 1. Linear layer which takes in an input of image_size as 64 and hidden size 256
# 2. The output of the linear layer is passed through a ReLU activation function
# 3. The result of the activation function is then passed through a Linear layer which takes in 256 input and produces 256 outputs
# 4. This result is again passed through a leaky relu layer.
# 5. Finally the output is passed through a Linear layer and the result is passed through the tanh() function.

G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# **Step3. Attempt to save and display at least 3 samples produced from your GAN model. Describe and discuss any difficulties faced in this process.**

# %%
y = G(torch.randn(3, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %%
plt.imshow(gen_imgs[2], cmap='gray');

# %%
D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %% [markdown]
# Training the Discriminator starts with defining the loss and optimizier. The Discriminator need to identify between real and fake images, it is binary classification and hence use the Binary class entropy for the loss calculation. Using the Adam optimizer to perform gradient descent.
#
# The discriminator will class all images from the data_loader dataset which is the FASHIONMNIST dataset as real images and the images from Generator as fake images. We find the loss for the images from the MNIST dataset by setting the labels to be compared with in the loss function as 1 and vice versa for the images generated by the generator. After we have calculated the loss for both the real and fake set of images, we add the two losses as the net loss for the discriminator. You can also observe that only the gradients of the discriminator is being calculated and not that of the generator as in this piece of code we are only training the discriminator.

# %%
# Define the loss and optimizer

criterion = nn.BCELoss()

# Optimizer for Discriminator
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
#Training the discriminator

def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # So essentially, you use the given set of real images and feed it to the discriminator and train to understand the pattern of the real images.
    # Then, you generate a bunch of fake images and then feed them to the discriminator to train them to understand the pattern of the fake images.

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Training the Generator. A batch of images are generated by the Generator. These images are passed to the Discriminator with label 1 saying they are the real images. This will calculate how far the real images are from the fake ones, calculate the loss.
#
# At the end of the function we see that the weights of the Generator are updated but the weights of the Discriminator stay the same.

# %%
# Optimizer for the Generator

g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    # Assuming 'fake_images' is a tensor you've generated
    #fake_images = ... # Your code to generate or get fake images
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    fake_fname = 'fake_images-{index:04d}-{timestamp}.png'.format(index=index, timestamp=timestamp)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# %%
# Before training

save_fake_images(0)
# Out:
# Saving fake_images-0000-20240305_040723.png

# %%
#save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000-20240305_040723.png'))

# %%
# %%time

num_epochs = 20
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/20], Step [200/600], d_loss: 0.0971, g_loss: 3.8494, D(x): 0.97, D(G(z)): 0.06
# Epoch [0/20], Step [400/600], d_loss: 0.0639, g_loss: 4.7454, D(x): 0.99, D(G(z)): 0.05
# Epoch [0/20], Step [600/600], d_loss: 0.0812, g_loss: 4.2983, D(x): 0.96, D(G(z)): 0.04
# Saving fake_images-0001-20240305_040830.png
# Epoch [1/20], Step [200/600], d_loss: 0.0582, g_loss: 4.3943, D(x): 0.99, D(G(z)): 0.04
# Epoch [1/20], Step [400/600], d_loss: 0.0307, g_loss: 4.5947, D(x): 0.99, D(G(z)): 0.02
# Epoch [1/20], Step [600/600], d_loss: 0.0530, g_loss: 5.7958, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0002-20240305_040908.png
# Epoch [2/20], Step [200/600], d_loss: 0.0224, g_loss: 6.6844, D(x): 0.99, D(G(z)): 0.00
# Epoch [2/20], Step [400/600], d_loss: 0.0496, g_loss: 6.8955, D(x): 0.99, D(G(z)): 0.02
# Epoch [2/20], Step [600/600], d_loss: 0.0643, g_loss: 7.1534, D(x): 0.99, D(G(z)): 0.04
# Saving fake_images-0003-20240305_040943.png
# Epoch [3/20], Step [200/600], d_loss: 0.1754, g_loss: 6.5478, D(x): 0.98, D(G(z)): 0.09
# Epoch [3/20], Step [400/600], d_loss: 0.0078, g_loss: 8.6098, D(x): 1.00, D(G(z)): 0.01
# Epoch [3/20], Step [600/600], d_loss: 0.0873, g_loss: 5.0783, D(x): 0.96, D(G(z)): 0.03
# Saving fake_images-0004-20240305_041020.png
# Epoch [4/20], Step [200/600], d_loss: 0.3222, g_loss: 4.1929, D(x): 0.89, D(G(z)): 0.03
# Epoch [4/20], Step [400/600], d_loss: 0.0637, g_loss: 5.7944, D(x): 0.98, D(G(z)): 0.03
# Epoch [4/20], Step [600/600], d_loss: 0.0732, g_loss: 7.5906, D(x): 0.97, D(G(z)): 0.00
# Saving fake_images-0005-20240305_041054.png
# Epoch [5/20], Step [200/600], d_loss: 0.1470, g_loss: 5.3495, D(x): 0.94, D(G(z)): 0.02
# Epoch [5/20], Step [400/600], d_loss: 0.1502, g_loss: 5.1016, D(x): 0.95, D(G(z)): 0.02
# Epoch [5/20], Step [600/600], d_loss: 0.1518, g_loss: 4.6667, D(x): 0.95, D(G(z)): 0.02
# Saving fake_images-0006-20240305_041130.png
# Epoch [6/20], Step [200/600], d_loss: 0.0836, g_loss: 6.0329, D(x): 0.97, D(G(z)): 0.02
# Epoch [6/20], Step [400/600], d_loss: 0.0782, g_loss: 5.3195, D(x): 0.98, D(G(z)): 0.02
# Epoch [6/20], Step [600/600], d_loss: 0.1220, g_loss: 4.5886, D(x): 0.96, D(G(z)): 0.04
# Saving fake_images-0007-20240305_041204.png
# Epoch [7/20], Step [200/600], d_loss: 0.1564, g_loss: 5.3938, D(x): 0.99, D(G(z)): 0.10
# Epoch [7/20], Step [400/600], d_loss: 0.2145, g_loss: 6.2462, D(x): 0.94, D(G(z)): 0.03
# Epoch [7/20], Step [600/600], d_loss: 0.1582, g_loss: 7.3514, D(x): 0.96, D(G(z)): 0.03
# Saving fake_images-0008-20240305_041240.png
# Epoch [8/20], Step [200/600], d_loss: 0.0753, g_loss: 4.7356, D(x): 0.98, D(G(z)): 0.04
# Epoch [8/20], Step [400/600], d_loss: 0.1138, g_loss: 5.2055, D(x): 0.96, D(G(z)): 0.03
# Epoch [8/20], Step [600/600], d_loss: 0.2140, g_loss: 6.1674, D(x): 0.95, D(G(z)): 0.03
# Saving fake_images-0009-20240305_041316.png
# Epoch [9/20], Step [200/600], d_loss: 0.2021, g_loss: 4.9451, D(x): 0.92, D(G(z)): 0.03
# Epoch [9/20], Step [400/600], d_loss: 0.2150, g_loss: 4.6064, D(x): 0.94, D(G(z)): 0.04
# Epoch [9/20], Step [600/600], d_loss: 0.3183, g_loss: 5.9047, D(x): 0.91, D(G(z)): 0.06
# Saving fake_images-0010-20240305_041351.png
# Epoch [10/20], Step [200/600], d_loss: 0.3358, g_loss: 6.3662, D(x): 0.87, D(G(z)): 0.02
# Epoch [10/20], Step [400/600], d_loss: 0.2982, g_loss: 4.9277, D(x): 0.91, D(G(z)): 0.03
# Epoch [10/20], Step [600/600], d_loss: 0.2064, g_loss: 6.3584, D(x): 0.93, D(G(z)): 0.02
# Saving fake_images-0011-20240305_041427.png
# Epoch [11/20], Step [200/600], d_loss: 0.1884, g_loss: 4.3718, D(x): 0.95, D(G(z)): 0.06
# Epoch [11/20], Step [400/600], d_loss: 0.1411, g_loss: 4.0824, D(x): 0.97, D(G(z)): 0.07
# Epoch [11/20], Step [600/600], d_loss: 0.2349, g_loss: 4.4765, D(x): 0.92, D(G(z)): 0.07
# Saving fake_images-0012-20240305_041502.png
# Epoch [12/20], Step [200/600], d_loss: 0.3152, g_loss: 4.3819, D(x): 0.90, D(G(z)): 0.10
# Epoch [12/20], Step [400/600], d_loss: 0.2846, g_loss: 3.7025, D(x): 0.95, D(G(z)): 0.13
# Epoch [12/20], Step [600/600], d_loss: 0.2751, g_loss: 3.1789, D(x): 0.95, D(G(z)): 0.11
# Saving fake_images-0013-20240305_041539.png
# Epoch [13/20], Step [200/600], d_loss: 0.2028, g_loss: 3.2020, D(x): 0.95, D(G(z)): 0.07
# Epoch [13/20], Step [400/600], d_loss: 0.3839, g_loss: 5.0881, D(x): 0.85, D(G(z)): 0.02
# Epoch [13/20], Step [600/600], d_loss: 0.4149, g_loss: 4.6732, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0014-20240305_041614.png
# Epoch [14/20], Step [200/600], d_loss: 0.2487, g_loss: 4.5614, D(x): 0.93, D(G(z)): 0.09
# Epoch [14/20], Step [400/600], d_loss: 0.2216, g_loss: 2.9338, D(x): 0.93, D(G(z)): 0.07
# Epoch [14/20], Step [600/600], d_loss: 0.1981, g_loss: 4.6799, D(x): 0.93, D(G(z)): 0.07
# Saving fake_images-0015-20240305_041651.png
# Epoch [15/20], Step [200/600], d_loss: 0.4910, g_loss: 3.7344, D(x): 0.86, D(G(z)): 0.13
# Epoch [15/20], Step [400/600], d_loss: 0.3460, g_loss: 3.0460, D(x): 0.90, D(G(z)): 0.14
# Epoch [15/20], Step [600/600], d_loss: 0.2587, g_loss: 3.4000, D(x): 0.93, D(G(z)): 0.11
# Saving fake_images-0016-20240305_041726.png
# Epoch [16/20], Step [200/600], d_loss: 0.3211, g_loss: 3.7231, D(x): 0.91, D(G(z)): 0.09
# Epoch [16/20], Step [400/600], d_loss: 0.3182, g_loss: 3.8572, D(x): 0.89, D(G(z)): 0.09
# Epoch [16/20], Step [600/600], d_loss: 0.2549, g_loss: 4.1553, D(x): 0.89, D(G(z)): 0.04
# Saving fake_images-0017-20240305_041802.png
# Epoch [17/20], Step [200/600], d_loss: 0.4282, g_loss: 3.7255, D(x): 0.91, D(G(z)): 0.17
# Epoch [17/20], Step [400/600], d_loss: 0.4928, g_loss: 3.3057, D(x): 0.87, D(G(z)): 0.19
# Epoch [17/20], Step [600/600], d_loss: 0.3227, g_loss: 3.6461, D(x): 0.90, D(G(z)): 0.14
# Saving fake_images-0018-20240305_041838.png
# Epoch [18/20], Step [200/600], d_loss: 0.4249, g_loss: 3.6132, D(x): 0.95, D(G(z)): 0.19
# Epoch [18/20], Step [400/600], d_loss: 0.2540, g_loss: 3.9136, D(x): 0.92, D(G(z)): 0.10
# Epoch [18/20], Step [600/600], d_loss: 0.3449, g_loss: 3.4891, D(x): 0.95, D(G(z)): 0.18
# Saving fake_images-0019-20240305_041914.png
# Epoch [19/20], Step [200/600], d_loss: 0.4860, g_loss: 3.0143, D(x): 0.91, D(G(z)): 0.15
# Epoch [19/20], Step [400/600], d_loss: 0.3807, g_loss: 3.2888, D(x): 0.87, D(G(z)): 0.09
# Epoch [19/20], Step [600/600], d_loss: 0.3282, g_loss: 2.8789, D(x): 0.90, D(G(z)): 0.13
# Saving fake_images-0020-20240305_041949.png
# CPU times: user 11min 34s, sys: 6.45 s, total: 11min 40s
# Wall time: 11min 53s

# %% [markdown]
# Check some of the saved images created by the Generator

# %%
Image(os.path.join(sample_dir, 'fake_images-0001-20240305_040830.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0002-20240305_040908.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0014-20240305_041614.png'))

# %%
# Last image in epoch
Image(os.path.join(sample_dir, 'fake_images-0020-20240305_041949.png'))

# %% [markdown]
# View the losses and accuracies

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# **Step4. Save the model weights in the folder to be used later.**

# %%
# Save checkpoint function saves the state dictionaries for model and optimizer
# Save the model checkpoints

# Define your checkpoint directory and prefix
checkpoint_dir = './training_checkpoints_10E'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

# Ensure the checkpoint directory exists
os.makedirs(checkpoint_dir, exist_ok=True)

# To save a checkpoint
def save_checkpoint(epoch, genG, discriM, g_optimizer, d_optimizer, filename="checkpoint.pth.tar"):
    save_path = os.path.join(checkpoint_dir, f"{filename}_{epoch}")
    torch.save({
        'Generator': G.state_dict(),
        'Discriminator': D.state_dict(),
        'G_optimizer_state_dict': g_optimizer.state_dict(),
        'D_optimizer_state_dict': d_optimizer.state_dict(),
    }, save_path)
    print(f"Checkpoint saved to {save_path}")

# %%
torch.save(G.state_dict(), 'G_fashion_mnist.pth')
torch.save(D.state_dict(), 'D_fashion_mnist.pth')

# %%
# Set path to save the models

G.load_state_dict(torch.load('G_fashion_mnist.pth'))
D.load_state_dict(torch.load('D_fashion_mnist.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Save the models

# %%
checkpoint = save_checkpoint(num_epochs, G, D, g_optimizer, d_optimizer)
# Out:
# Checkpoint saved to ./training_checkpoints_10E/checkpoint.pth.tar_20

# %% [markdown]
# **Step5. Load the model using the saved weights.**

# %%
# To load a checkpoint, loads the state dictionaries for model and optimizer

def load_checkpoint(model_path, genG, discriM, genG_optimizer, discriM_optimizer):
    checkpoint = torch.load(model_path)
    genG.load_state_dict(checkpoint['Generator'])
    discriM.load_state_dict(checkpoint['Discriminator'])
    genG_optimizer.load_state_dict(checkpoint['G_optimizer_state_dict'])
    discriM_optimizer.load_state_dict(checkpoint['D_optimizer_state_dict'])
    print(f"Checkpoint loaded from {model_path}")

# %%
# Define the location of the model to load
checkpoint_dir = './training_checkpoints_10E'
filename="checkpoint.pth.tar_20"
file_path = os.path.join(checkpoint_dir, filename)

load_model = load_checkpoint(file_path, G, D, g_optimizer, d_optimizer)
# Out:
# Checkpoint loaded from ./training_checkpoints_10E/checkpoint.pth.tar_20

# %% [markdown]
# **Step 6: Re-train the GAN model to see if you can improve.**

# %%
# %%time

num_epochs = 20
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/20], Step [200/600], d_loss: 0.3714, g_loss: 3.5354, D(x): 0.94, D(G(z)): 0.19
# Epoch [0/20], Step [400/600], d_loss: 0.7338, g_loss: 3.2126, D(x): 0.91, D(G(z)): 0.30
# Epoch [0/20], Step [600/600], d_loss: 0.4706, g_loss: 3.1580, D(x): 0.88, D(G(z)): 0.18
# Saving fake_images-0001-20240305_043049.png
# Epoch [1/20], Step [200/600], d_loss: 0.3543, g_loss: 2.4862, D(x): 0.90, D(G(z)): 0.15
# Epoch [1/20], Step [400/600], d_loss: 0.5315, g_loss: 2.9735, D(x): 0.83, D(G(z)): 0.13
# Epoch [1/20], Step [600/600], d_loss: 0.3802, g_loss: 3.2885, D(x): 0.90, D(G(z)): 0.16
# Saving fake_images-0002-20240305_043125.png
# Epoch [2/20], Step [200/600], d_loss: 0.4752, g_loss: 4.5797, D(x): 0.84, D(G(z)): 0.09
# Epoch [2/20], Step [400/600], d_loss: 0.4356, g_loss: 4.0626, D(x): 0.93, D(G(z)): 0.19
# Epoch [2/20], Step [600/600], d_loss: 0.4354, g_loss: 3.6081, D(x): 0.88, D(G(z)): 0.13
# Saving fake_images-0003-20240305_043200.png
# Epoch [3/20], Step [200/600], d_loss: 0.3212, g_loss: 3.4160, D(x): 0.89, D(G(z)): 0.10
# Epoch [3/20], Step [400/600], d_loss: 0.3888, g_loss: 3.7402, D(x): 0.83, D(G(z)): 0.04
# Epoch [3/20], Step [600/600], d_loss: 0.4356, g_loss: 2.7955, D(x): 0.87, D(G(z)): 0.16
# Saving fake_images-0004-20240305_043236.png
# Epoch [4/20], Step [200/600], d_loss: 0.5034, g_loss: 3.1869, D(x): 0.85, D(G(z)): 0.13
# Epoch [4/20], Step [400/600], d_loss: 0.2444, g_loss: 3.1831, D(x): 0.92, D(G(z)): 0.08
# Epoch [4/20], Step [600/600], d_loss: 0.5091, g_loss: 3.6627, D(x): 0.90, D(G(z)): 0.21
# Saving fake_images-0005-20240305_043311.png
# Epoch [5/20], Step [200/600], d_loss: 0.5312, g_loss: 3.4668, D(x): 0.83, D(G(z)): 0.12
# Epoch [5/20], Step [400/600], d_loss: 0.3600, g_loss: 5.0312, D(x): 0.86, D(G(z)): 0.07
# Epoch [5/20], Step [600/600], d_loss: 0.2891, g_loss: 3.8976, D(x): 0.90, D(G(z)): 0.09
# Saving fake_images-0006-20240305_043347.png
# Epoch [6/20], Step [200/600], d_loss: 0.5877, g_loss: 3.1919, D(x): 0.91, D(G(z)): 0.20
# Epoch [6/20], Step [400/600], d_loss: 0.5331, g_loss: 3.4270, D(x): 0.78, D(G(z)): 0.05
# Epoch [6/20], Step [600/600], d_loss: 0.4582, g_loss: 3.4471, D(x): 0.86, D(G(z)): 0.12
# Saving fake_images-0007-20240305_043422.png
# Epoch [7/20], Step [200/600], d_loss: 0.3762, g_loss: 3.7394, D(x): 0.86, D(G(z)): 0.06
# Epoch [7/20], Step [400/600], d_loss: 0.6281, g_loss: 3.0045, D(x): 0.77, D(G(z)): 0.11
# Epoch [7/20], Step [600/600], d_loss: 0.6345, g_loss: 2.6034, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0008-20240305_043458.png
# Epoch [8/20], Step [200/600], d_loss: 0.4267, g_loss: 2.6927, D(x): 0.86, D(G(z)): 0.08
# Epoch [8/20], Step [400/600], d_loss: 0.5775, g_loss: 3.2202, D(x): 0.82, D(G(z)): 0.11
# Epoch [8/20], Step [600/600], d_loss: 0.6252, g_loss: 3.8518, D(x): 0.76, D(G(z)): 0.08
# Saving fake_images-0009-20240305_043533.png
# Epoch [9/20], Step [200/600], d_loss: 0.7478, g_loss: 2.3753, D(x): 0.76, D(G(z)): 0.14
# Epoch [9/20], Step [400/600], d_loss: 0.5122, g_loss: 2.7353, D(x): 0.84, D(G(z)): 0.17
# Epoch [9/20], Step [600/600], d_loss: 0.7045, g_loss: 2.7165, D(x): 0.79, D(G(z)): 0.11
# Saving fake_images-0010-20240305_043609.png
# Epoch [10/20], Step [200/600], d_loss: 0.4610, g_loss: 4.1493, D(x): 0.85, D(G(z)): 0.14
# Epoch [10/20], Step [400/600], d_loss: 0.2928, g_loss: 4.0564, D(x): 0.92, D(G(z)): 0.10
# Epoch [10/20], Step [600/600], d_loss: 0.5435, g_loss: 3.5393, D(x): 0.81, D(G(z)): 0.12
# Saving fake_images-0011-20240305_043645.png
# Epoch [11/20], Step [200/600], d_loss: 0.5588, g_loss: 3.0657, D(x): 0.84, D(G(z)): 0.17
# Epoch [11/20], Step [400/600], d_loss: 0.6974, g_loss: 2.8228, D(x): 0.82, D(G(z)): 0.23
# Epoch [11/20], Step [600/600], d_loss: 0.7260, g_loss: 2.9171, D(x): 0.85, D(G(z)): 0.25
# Saving fake_images-0012-20240305_043721.png
# Epoch [12/20], Step [200/600], d_loss: 0.3723, g_loss: 3.4620, D(x): 0.89, D(G(z)): 0.10
# Epoch [12/20], Step [400/600], d_loss: 0.4391, g_loss: 3.4861, D(x): 0.90, D(G(z)): 0.16
# Epoch [12/20], Step [600/600], d_loss: 0.5506, g_loss: 3.4383, D(x): 0.81, D(G(z)): 0.12
# Saving fake_images-0013-20240305_043757.png
# Epoch [13/20], Step [200/600], d_loss: 0.4669, g_loss: 3.1113, D(x): 0.88, D(G(z)): 0.16
# Epoch [13/20], Step [400/600], d_loss: 0.2378, g_loss: 4.0691, D(x): 0.91, D(G(z)): 0.09
# Epoch [13/20], Step [600/600], d_loss: 0.4009, g_loss: 3.4507, D(x): 0.87, D(G(z)): 0.14
# Saving fake_images-0014-20240305_043832.png
# Epoch [14/20], Step [200/600], d_loss: 0.2969, g_loss: 3.2474, D(x): 0.93, D(G(z)): 0.14
# Epoch [14/20], Step [400/600], d_loss: 0.6636, g_loss: 2.6003, D(x): 0.81, D(G(z)): 0.17
# Epoch [14/20], Step [600/600], d_loss: 0.5768, g_loss: 3.0825, D(x): 0.79, D(G(z)): 0.12
# Saving fake_images-0015-20240305_043908.png
# Epoch [15/20], Step [200/600], d_loss: 0.7362, g_loss: 2.5911, D(x): 0.82, D(G(z)): 0.18
# Epoch [15/20], Step [400/600], d_loss: 0.6378, g_loss: 2.6127, D(x): 0.85, D(G(z)): 0.25
# Epoch [15/20], Step [600/600], d_loss: 0.6867, g_loss: 2.5819, D(x): 0.81, D(G(z)): 0.19
# Saving fake_images-0016-20240305_043944.png
# Epoch [16/20], Step [200/600], d_loss: 0.4732, g_loss: 3.4222, D(x): 0.86, D(G(z)): 0.17
# Epoch [16/20], Step [400/600], d_loss: 0.5424, g_loss: 2.3496, D(x): 0.81, D(G(z)): 0.12
# Epoch [16/20], Step [600/600], d_loss: 0.4400, g_loss: 3.3509, D(x): 0.82, D(G(z)): 0.12
# Saving fake_images-0017-20240305_044020.png
# Epoch [17/20], Step [200/600], d_loss: 0.6928, g_loss: 2.5420, D(x): 0.81, D(G(z)): 0.22
# Epoch [17/20], Step [400/600], d_loss: 0.5935, g_loss: 3.7797, D(x): 0.79, D(G(z)): 0.09
# Epoch [17/20], Step [600/600], d_loss: 0.5631, g_loss: 2.9634, D(x): 0.85, D(G(z)): 0.19
# Saving fake_images-0018-20240305_044057.png
# Epoch [18/20], Step [200/600], d_loss: 0.7023, g_loss: 2.4429, D(x): 0.74, D(G(z)): 0.14
# Epoch [18/20], Step [400/600], d_loss: 0.5442, g_loss: 2.8489, D(x): 0.82, D(G(z)): 0.11
# Epoch [18/20], Step [600/600], d_loss: 0.4624, g_loss: 2.6819, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0019-20240305_044133.png
# Epoch [19/20], Step [200/600], d_loss: 0.6729, g_loss: 3.2756, D(x): 0.78, D(G(z)): 0.12
# Epoch [19/20], Step [400/600], d_loss: 0.7033, g_loss: 2.6277, D(x): 0.77, D(G(z)): 0.14
# Epoch [19/20], Step [600/600], d_loss: 0.6480, g_loss: 2.6928, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0020-20240305_044209.png
# CPU times: user 11min 43s, sys: 2.81 s, total: 11min 46s
# Wall time: 11min 56s

# %%
# Show images from the loaded model
Image(os.path.join(sample_dir, 'fake_images-0001-20240305_043049.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0020-20240305_044209.png'))

# %%
# Show plot of real and fake scores

plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# **Step 7: Save the model weights without using checkpoints.**

# %%
# specify a path to save models

save_directory = './saved_models'

# Check if the directory exists, and if not, create it
if not os.path.exists(save_directory):
    os.makedirs(save_directory)

# Save weights without check point
torch.save(G.state_dict, os.path.join(save_directory, 'G_weights.pth'))
torch.save(D.state_dict, os.path.join(save_directory, 'D_weights.pth'))

# %% [markdown]
# **Step 8: Load the model weights without using checkpoints.**

# %%
# Load the models again

genG = G.to(device)
discriM = D.to(device)

# Load generator and discriminator weights
genG_weights = torch.load(os.path.join(save_directory, 'G_weights.pth'))
discriM_weights = torch.load(os.path.join(save_directory, 'D_weights.pth'))
