# %%
# Mount to Google drive
from google.colab import drive
drive.mount('/content/drive/')

# Navigate to necessary folder
# %cd '/content/drive/My Drive/Data 255 Spring 2024/Google Colab/Homework5'
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/Data 255 Spring 2024/Google Colab/Homework5

# %% [markdown]
# **Step1. Load the Fashion MNIST dataset and replace the original dataset used in the demo.**

# %%
# Import necessary libraries

import torch
import torchvision
import torch.nn as nn
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
import torchvision.utils as vutils
# Predefined fuction to save images
from torchvision.utils import save_image

import matplotlib.pyplot as plt
# %matplotlib inline
import os
from IPython.display import Image

# %%
# Device configuration,GPU or the CPU is checked in this block

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
#Load the dataset, train dataset, and transform to tensor, data preprocessing task

mnist = FashionMNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %%
#Viewing the data

img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %%
# Viewing the images we would like to de normalize it
# Currently the image is normalized to [-,1,1[] and we convert
# back to [0,1[] to show the image. Tensor x on adding one shifts from
# [-1,1] to [0,2] and divding by 2 give [0,1]. Clamp makes sure
# values outside of [0,1] are set to 0 or 1

def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
# Set variables

# Size of each batch
batch_size = 100
# image size 28*28
image_size = 784

hidden_size = 256
# Dimentionality of the latent space, larger latent space
# captures more intricate patterns, but also requires more resources
latent_size = 64

# %%
#To ensure that the data is loaded in batches during training we are using a DataLoader.

data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
# Plot some training images
import numpy as np

real_batch = next(iter(data_loader))
plt.figure(figsize=(5, 5))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
# Create a directory to save the real image

sample_dir = 'samples_chk'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
# Save real image

for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

# Show the real image - which is the first batch of 100 images
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# **Step2. Train the GAN model to produce images in this new domain.**

# %% [markdown]
# Define the **Discriminator**

# %%
#Define a pretty simple Disriminator network which has:
# 1. Linear layer which takes in an input of image_size as 784 and hidden size 256
# 2. The output of the linear layer is passed through a ReLU activation function
# 3. The result of the activation function is then passed through a Linear layer which takes in 256 input and produces 256 outputs
# 4. This result is again passed through a leaky relu layer.
# 5. Finally the output is passed through a Linear layer and the result is passed through the sigmoid function.

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# Define the **Generator**

# %%
#Define a pretty simple Generator network which has:
# 1. Linear layer which takes in an input of image_size as 64 and hidden size 256
# 2. The output of the linear layer is passed through a ReLU activation function
# 3. The result of the activation function is then passed through a Linear layer which takes in 256 input and produces 256 outputs
# 4. This result is again passed through a leaky relu layer.
# 5. Finally the output is passed through a Linear layer and the result is passed through the tanh() function.

G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# **Step3. Attempt to save and display at least 3 samples produced from your GAN model. Describe and discuss any difficulties faced in this process.**

# %%
y = G(torch.randn(3, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %%
plt.imshow(gen_imgs[2], cmap='gray');

# %%
D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %% [markdown]
# Training the Discriminator starts with defining the loss and optimizier. The Discriminator need to identify between real and fake images, it is binary classification and hence use the Binary class entropy for the loss calculation. Using the Adam optimizer to perform gradient descent.
#
# The discriminator will class all images from the data_loader dataset which is the FASHIONMNIST dataset as real images and the images from Generator as fake images. We find the loss for the images from the MNIST dataset by setting the labels to be compared with in the loss function as 1 and vice versa for the images generated by the generator. After we have calculated the loss for both the real and fake set of images, we add the two losses as the net loss for the discriminator. You can also observe that only the gradients of the discriminator is being calculated and not that of the generator as in this piece of code we are only training the discriminator.

# %%
# Define the loss and optimizer

criterion = nn.BCELoss()

# Optimizer for Discriminator
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
#Training the discriminator

def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # So essentially, you use the given set of real images and feed it to the discriminator and train to understand the pattern of the real images.
    # Then, you generate a bunch of fake images and then feed them to the discriminator to train them to understand the pattern of the fake images.

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Training the Generator. A batch of images are generated by the Generator. These images are passed to the Discriminator with label 1 saying they are the real images. This will calculate how far the real images are from the fake ones, calculate the loss.
#
# At the end of the function we see that the weights of the Generator are updated but the weights of the Discriminator stay the same.

# %%
# Optimizer for the Generator

g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %%
# Create a directory to save the intermediate pics the Generator has created
# Define sample vector

sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# %%
# Before training

save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.1179, g_loss: 3.6440, D(x): 0.97, D(G(z)): 0.08
# Epoch [0/300], Step [400/600], d_loss: 0.1046, g_loss: 5.2674, D(x): 0.95, D(G(z)): 0.04
# Epoch [0/300], Step [600/600], d_loss: 0.0253, g_loss: 5.1690, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0397, g_loss: 4.7277, D(x): 0.99, D(G(z)): 0.02
# Epoch [1/300], Step [400/600], d_loss: 0.0416, g_loss: 4.6922, D(x): 0.99, D(G(z)): 0.02
# Epoch [1/300], Step [600/600], d_loss: 0.0292, g_loss: 5.2460, D(x): 0.99, D(G(z)): 0.01
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.1454, g_loss: 4.8897, D(x): 0.94, D(G(z)): 0.01
# Epoch [2/300], Step [400/600], d_loss: 0.0144, g_loss: 6.4424, D(x): 0.99, D(G(z)): 0.01
# Epoch [2/300], Step [600/600], d_loss: 0.0106, g_loss: 7.7511, D(x): 0.99, D(G(z)): 0.00
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.0437, g_loss: 6.2366, D(x): 1.00, D(G(z)): 0.04
# Epoch [3/300], Step [400/600], d_loss: 0.2500, g_loss: 7.2772, D(x): 0.90, D(G(z)): 0.00
# Epoch [3/300], Step [600/600], d_loss: 0.0101, g_loss: 7.1197, D(x): 1.00, D(G(z)): 0.01
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.0905, g_loss: 4.5439, D(x): 0.97, D(G(z)): 0.04
# Epoch [4/300], Step [400/600], d_loss: 0.1170, g_loss: 7.4284, D(x): 0.95, D(G(z)): 0.02
# Epoch [4/300], Step [600/600], d_loss: 0.0578, g_loss: 5.8778, D(x): 0.97, D(G(z)): 0.02
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.1522, g_loss: 6.2128, D(x): 0.96, D(G(z)): 0.00
# Epoch [5/300], Step [400/600], d_loss: 0.0374, g_loss: 7.1487, D(x): 0.98, D(G(z)): 0.01
# Epoch [5/300], Step [600/600], d_loss: 0.1445, g_loss: 5.8005, D(x): 0.99, D(G(z)): 0.10
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.0287, g_loss: 6.5326, D(x): 0.99, D(G(z)): 0.01
# Epoch [6/300], Step [400/600], d_loss: 0.2109, g_loss: 5.3695, D(x): 0.95, D(G(z)): 0.04
# Epoch [6/300], Step [600/600], d_loss: 0.1690, g_loss: 3.8565, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.0583, g_loss: 6.8544, D(x): 0.98, D(G(z)): 0.02
# Epoch [7/300], Step [400/600], d_loss: 0.0959, g_loss: 4.8067, D(x): 0.97, D(G(z)): 0.02
# Epoch [7/300], Step [600/600], d_loss: 0.2142, g_loss: 3.5135, D(x): 0.95, D(G(z)): 0.07
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1980, g_loss: 4.3545, D(x): 0.96, D(G(z)): 0.11
# Epoch [8/300], Step [400/600], d_loss: 0.1114, g_loss: 4.1756, D(x): 0.97, D(G(z)): 0.05
# Epoch [8/300], Step [600/600], d_loss: 0.2522, g_loss: 5.1258, D(x): 0.95, D(G(z)): 0.08
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.1178, g_loss: 5.0908, D(x): 0.95, D(G(z)): 0.02
# Epoch [9/300], Step [400/600], d_loss: 0.1966, g_loss: 4.3980, D(x): 0.96, D(G(z)): 0.07
# Epoch [9/300], Step [600/600], d_loss: 0.1132, g_loss: 5.8783, D(x): 0.97, D(G(z)): 0.05
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.2124, g_loss: 4.9533, D(x): 0.92, D(G(z)): 0.03
# Epoch [10/300], Step [400/600], d_loss: 0.1832, g_loss: 6.8884, D(x): 0.93, D(G(z)): 0.03
# Epoch [10/300], Step [600/600], d_loss: 0.1819, g_loss: 5.3872, D(x): 0.96, D(G(z)): 0.08
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.2848, g_loss: 3.3032, D(x): 0.92, D(G(z)): 0.10
# Epoch [11/300], Step [400/600], d_loss: 0.4367, g_loss: 3.6051, D(x): 0.92, D(G(z)): 0.16
# Epoch [11/300], Step [600/600], d_loss: 0.1672, g_loss: 3.6169, D(x): 0.95, D(G(z)): 0.07
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.2115, g_loss: 3.4203, D(x): 0.93, D(G(z)): 0.08
# Epoch [12/300], Step [400/600], d_loss: 0.2258, g_loss: 4.3335, D(x): 0.93, D(G(z)): 0.09
# Epoch [12/300], Step [600/600], d_loss: 0.2609, g_loss: 3.8778, D(x): 0.92, D(G(z)): 0.07
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.1915, g_loss: 6.2013, D(x): 0.94, D(G(z)): 0.03
# Epoch [13/300], Step [400/600], d_loss: 0.2087, g_loss: 3.5801, D(x): 0.93, D(G(z)): 0.09
# Epoch [13/300], Step [600/600], d_loss: 0.6034, g_loss: 3.7564, D(x): 0.88, D(G(z)): 0.12
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.2835, g_loss: 3.2521, D(x): 0.90, D(G(z)): 0.07
# Epoch [14/300], Step [400/600], d_loss: 0.3248, g_loss: 3.6867, D(x): 0.89, D(G(z)): 0.05
# Epoch [14/300], Step [600/600], d_loss: 0.3360, g_loss: 3.2468, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.4680, g_loss: 3.8714, D(x): 0.89, D(G(z)): 0.08
# Epoch [15/300], Step [400/600], d_loss: 0.4048, g_loss: 2.5985, D(x): 0.88, D(G(z)): 0.13
# Epoch [15/300], Step [600/600], d_loss: 0.3837, g_loss: 2.9534, D(x): 0.93, D(G(z)): 0.19
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.3835, g_loss: 2.7458, D(x): 0.98, D(G(z)): 0.25
# Epoch [16/300], Step [400/600], d_loss: 0.3437, g_loss: 4.1375, D(x): 0.90, D(G(z)): 0.09
# Epoch [16/300], Step [600/600], d_loss: 0.4515, g_loss: 3.1200, D(x): 0.92, D(G(z)): 0.20
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.3252, g_loss: 4.1772, D(x): 0.91, D(G(z)): 0.05
# Epoch [17/300], Step [400/600], d_loss: 0.3924, g_loss: 3.0300, D(x): 0.90, D(G(z)): 0.12
# Epoch [17/300], Step [600/600], d_loss: 0.2634, g_loss: 2.9679, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.3111, g_loss: 3.1065, D(x): 0.92, D(G(z)): 0.14
# Epoch [18/300], Step [400/600], d_loss: 0.4435, g_loss: 3.1889, D(x): 0.87, D(G(z)): 0.10
# Epoch [18/300], Step [600/600], d_loss: 0.3076, g_loss: 2.9226, D(x): 0.93, D(G(z)): 0.11
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.3373, g_loss: 3.5145, D(x): 0.91, D(G(z)): 0.07
# Epoch [19/300], Step [400/600], d_loss: 0.2474, g_loss: 5.0478, D(x): 0.93, D(G(z)): 0.07
# Epoch [19/300], Step [600/600], d_loss: 0.4540, g_loss: 2.9691, D(x): 0.84, D(G(z)): 0.11
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.3471, g_loss: 3.1339, D(x): 0.88, D(G(z)): 0.11
# Epoch [20/300], Step [400/600], d_loss: 0.5334, g_loss: 2.5498, D(x): 0.85, D(G(z)): 0.18
# Epoch [20/300], Step [600/600], d_loss: 0.3410, g_loss: 2.7050, D(x): 0.90, D(G(z)): 0.11
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.3928, g_loss: 3.3784, D(x): 0.88, D(G(z)): 0.07
# Epoch [21/300], Step [400/600], d_loss: 0.4084, g_loss: 4.3331, D(x): 0.85, D(G(z)): 0.05
# Epoch [21/300], Step [600/600], d_loss: 0.3528, g_loss: 3.6048, D(x): 0.89, D(G(z)): 0.10
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.4743, g_loss: 2.9685, D(x): 0.84, D(G(z)): 0.11
# Epoch [22/300], Step [400/600], d_loss: 0.2789, g_loss: 3.5026, D(x): 0.94, D(G(z)): 0.15
# Epoch [22/300], Step [600/600], d_loss: 0.2297, g_loss: 2.9240, D(x): 0.93, D(G(z)): 0.11
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.6535, g_loss: 1.9056, D(x): 0.83, D(G(z)): 0.12
# Epoch [23/300], Step [400/600], d_loss: 0.5158, g_loss: 3.2617, D(x): 0.91, D(G(z)): 0.20
# Epoch [23/300], Step [600/600], d_loss: 0.4271, g_loss: 2.9653, D(x): 0.90, D(G(z)): 0.15
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.3487, g_loss: 3.1871, D(x): 0.87, D(G(z)): 0.11
# Epoch [24/300], Step [400/600], d_loss: 0.4249, g_loss: 2.9780, D(x): 0.89, D(G(z)): 0.19
# Epoch [24/300], Step [600/600], d_loss: 0.4135, g_loss: 2.7138, D(x): 0.89, D(G(z)): 0.17
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.5267, g_loss: 2.8704, D(x): 0.88, D(G(z)): 0.15
# Epoch [25/300], Step [400/600], d_loss: 0.2455, g_loss: 3.0027, D(x): 0.93, D(G(z)): 0.11
# Epoch [25/300], Step [600/600], d_loss: 0.4880, g_loss: 3.6246, D(x): 0.83, D(G(z)): 0.05
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.4634, g_loss: 3.6405, D(x): 0.84, D(G(z)): 0.11
# Epoch [46/300], Step [400/600], d_loss: 0.6558, g_loss: 3.1403, D(x): 0.82, D(G(z)): 0.22
# Epoch [46/300], Step [600/600], d_loss: 0.5398, g_loss: 3.1828, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.4716, g_loss: 2.9113, D(x): 0.82, D(G(z)): 0.12
# Epoch [47/300], Step [400/600], d_loss: 0.6743, g_loss: 2.6003, D(x): 0.90, D(G(z)): 0.29
# Epoch [47/300], Step [600/600], d_loss: 0.6525, g_loss: 2.0918, D(x): 0.81, D(G(z)): 0.23
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.5151, g_loss: 2.5533, D(x): 0.87, D(G(z)): 0.21
# Epoch [48/300], Step [400/600], d_loss: 0.5502, g_loss: 2.8120, D(x): 0.82, D(G(z)): 0.17
# Epoch [48/300], Step [600/600], d_loss: 0.5649, g_loss: 2.8616, D(x): 0.83, D(G(z)): 0.17
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.7403, g_loss: 3.4348, D(x): 0.76, D(G(z)): 0.13
# Epoch [49/300], Step [400/600], d_loss: 0.6641, g_loss: 1.9739, D(x): 0.82, D(G(z)): 0.24
# Epoch [49/300], Step [600/600], d_loss: 0.5242, g_loss: 1.9876, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.5997, g_loss: 2.2906, D(x): 0.88, D(G(z)): 0.26
# Epoch [50/300], Step [400/600], d_loss: 0.8373, g_loss: 1.9071, D(x): 0.75, D(G(z)): 0.20
# Epoch [50/300], Step [600/600], d_loss: 0.6908, g_loss: 2.3364, D(x): 0.84, D(G(z)): 0.26
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.5063, g_loss: 2.5816, D(x): 0.84, D(G(z)): 0.17
# Epoch [51/300], Step [400/600], d_loss: 0.5069, g_loss: 2.4739, D(x): 0.87, D(G(z)): 0.21
# Epoch [51/300], Step [600/600], d_loss: 0.6238, g_loss: 2.7395, D(x): 0.78, D(G(z)): 0.14
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.7247, g_loss: 3.0430, D(x): 0.83, D(G(z)): 0.29
# Epoch [52/300], Step [400/600], d_loss: 0.5492, g_loss: 2.6529, D(x): 0.85, D(G(z)): 0.21
# Epoch [52/300], Step [600/600], d_loss: 0.5481, g_loss: 2.2386, D(x): 0.82, D(G(z)): 0.19
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.6221, g_loss: 2.3742, D(x): 0.82, D(G(z)): 0.22
# Epoch [53/300], Step [400/600], d_loss: 0.4812, g_loss: 2.3212, D(x): 0.84, D(G(z)): 0.15
# Epoch [53/300], Step [600/600], d_loss: 0.5382, g_loss: 2.7156, D(x): 0.85, D(G(z)): 0.23
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.6321, g_loss: 2.0918, D(x): 0.84, D(G(z)): 0.26
# Epoch [54/300], Step [400/600], d_loss: 0.8066, g_loss: 3.0351, D(x): 0.82, D(G(z)): 0.25
# Epoch [54/300], Step [600/600], d_loss: 0.5841, g_loss: 2.5657, D(x): 0.80, D(G(z)): 0.15
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.5260, g_loss: 2.8177, D(x): 0.78, D(G(z)): 0.12
# Epoch [55/300], Step [400/600], d_loss: 1.0357, g_loss: 2.2098, D(x): 0.70, D(G(z)): 0.25
# Epoch [55/300], Step [600/600], d_loss: 0.7579, g_loss: 2.3426, D(x): 0.70, D(G(z)): 0.14
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0
D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 1.1816, g_loss: 1.3611, D(x): 0.60, D(G(z)): 0.35
# Epoch [278/300], Step [400/600], d_loss: 0.9814, g_loss: 1.4576, D(x): 0.64, D(G(z)): 0.31
# Epoch [278/300], Step [600/600], d_loss: 0.8519, g_loss: 1.4677, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.9352, g_loss: 1.2186, D(x): 0.70, D(G(z)): 0.35
# Epoch [279/300], Step [400/600], d_loss: 0.8782, g_loss: 1.7281, D(x): 0.67, D(G(z)): 0.27
# Epoch [279/300], Step [600/600], d_loss: 1.4743, g_loss: 1.1350, D(x): 0.60, D(G(z)): 0.44
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 1.4272, g_loss: 1.0364, D(x): 0.63, D(G(z)): 0.48
# Epoch [280/300], Step [400/600], d_loss: 0.9642, g_loss: 1.5435, D(x): 0.60, D(G(z)): 0.23
# Epoch [280/300], Step [600/600], d_loss: 0.9858, g_loss: 1.2312, D(x): 0.71, D(G(z)): 0.38
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.9901, g_loss: 1.6143, D(x): 0.66, D(G(z)): 0.31
# Epoch [281/300], Step [400/600], d_loss: 1.0620, g_loss: 1.3755, D(x): 0.69, D(G(z)): 0.38
# Epoch [281/300], Step [600/600], d_loss: 1.2701, g_loss: 1.3260, D(x): 0.61, D(G(z)): 0.39
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.7572, g_loss: 1.5729, D(x): 0.69, D(G(z)): 0.24
# Epoch [282/300], Step [400/600], d_loss: 0.8687, g_loss: 1.5985, D(x): 0.69, D(G(z)): 0.30
# Epoch [282/300], Step [600/600], d_loss: 0.8993, g_loss: 1.3950, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.7409, g_loss: 1.8326, D(x): 0.75, D(G(z)): 0.29
# Epoch [283/300], Step [400/600], d_loss: 0.7318, g_loss: 1.4507, D(x): 0.75, D(G(z)): 0.28
# Epoch [283/300], Step [600/600], d_loss: 1.0567, g_loss: 1.1485, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 1.0077, g_loss: 1.3076, D(x): 0.67, D(G(z)): 0.34
# Epoch [284/300], Step [400/600], d_loss: 1.0964, g_loss: 1.1031, D(x): 0.61, D(G(z)): 0.35
# Epoch [284/300], Step [600/600], d_loss: 1.3634, g_loss: 1.1243, D(x): 0.59, D(G(z)): 0.39
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 1.2357, g_loss: 1.1149, D(x): 0.65, D(G(z)): 0.43
# Epoch [285/300], Step [400/600], d_loss: 0.8893, g_loss: 1.5272, D(x): 0.70, D(G(z)): 0.31
# Epoch [285/300], Step [600/600], d_loss: 0.8645, g_loss: 1.6703, D(x): 0.75, D(G(z)): 0.31
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.8587, g_loss: 1.2786, D(x): 0.74, D(G(z)): 0.34
# Epoch [286/300], Step [400/600], d_loss: 1.1035, g_loss: 1.6476, D(x): 0.61, D(G(z)): 0.32
# Epoch [286/300], Step [600/600], d_loss: 1.0087, g_loss: 1.3595, D(x): 0.72, D(G(z)): 0.39
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.9692, g_loss: 1.4306, D(x): 0.68, D(G(z)): 0.33
# Epoch [287/300], Step [400/600], d_loss: 0.9772, g_loss: 1.2184, D(x): 0.71, D(G(z)): 0.37
# Epoch [287/300], Step [600/600], d_loss: 1.2111, g_loss: 1.2826, D(x): 0.61, D(G(z)): 0.37
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss:
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.8589, g_loss: 1.5629, D(x): 0.69, D(G(z)): 0.27
# Epoch [298/300], Step [400/600], d_loss: 0.9071, g_loss: 1.4829, D(x): 0.71, D(G(z)): 0.31
# Epoch [298/300], Step [600/600], d_loss: 0.8330, g_loss: 1.5907, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 1.5909, g_loss: 0.8440, D(x): 0.61, D(G(z)): 0.53
# Epoch [299/300], Step [400/600], d_loss: 1.0855, g_loss: 1.0409, D(x): 0.62, D(G(z)): 0.36
# Epoch [299/300], Step [600/600], d_loss: 0.7897, g_loss: 1.6532, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0300.png
# CPU times: user 2h 51min 16s, sys: 41.7 s, total: 2h 51min 58s
# Wall time: 2h 54min 5s

# %% [markdown]
# Check some of the saved images created by the Generator

# %%
Image('./samples_chk/fake_images-0001.png')

# %%
Image('./samples_chk/fake_images-0099.png')

# %%
Image('./samples_chk/fake_images-0200.png')

# %%
Image('./samples_chk/fake_images-0300.png')

# %% [markdown]
# View the losses and accuracies

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# #### GAN models are hard to train. I am showing the images for the trained data at image 1, 99, 200 and 300. There were a total of 300 epochs for this step. As you can see from the "Loss" graph, around 400th epoch the images would start to look more similar. Currently it took 3 hours for 300 epochs. More experiments need to be conducted by using different loss functions, or employing regularization methods. Even with a successfully trained GAN, the quality of the generated images might not perfectly match the real data distribution.

# %% [markdown]
# **Step4. Save the model weights in the folder to be used later.**

# %%
# Save checkpoint function saves the state dictionaries for model and optimizer
# Save the model checkpoints

# Define your checkpoint directory and prefix
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

# Ensure the checkpoint directory exists
os.makedirs(checkpoint_dir, exist_ok=True)

# To save a checkpoint
def save_checkpoint(epoch, genG, discriM, g_optimizer, d_optimizer, filename="checkpoint.pth.tar"):
    save_path = os.path.join(checkpoint_dir, f"{filename}_{epoch}")
    torch.save({
        'Generator': G.state_dict(),
        'Discriminator': D.state_dict(),
        'G_optimizer_state_dict': g_optimizer.state_dict(),
        'D_optimizer_state_dict': d_optimizer.state_dict(),
    }, save_path)
    print(f"Checkpoint saved to {save_path}")

# %%
checkpoint = save_checkpoint(num_epochs, G, D, g_optimizer, d_optimizer)
# Out:
# Checkpoint saved to ./training_checkpoints/checkpoint.pth.tar_300

# %% [markdown]
# **Step5. Load the model using the saved weights.**

# %%
# To load a checkpoint, loads the state dictionaries for model and optimizer

def load_checkpoint(model_path, genG, discriM, genG_optimizer, discriM_optimizer):
    checkpoint = torch.load(model_path)
    genG.load_state_dict(checkpoint['Generator'])
    discriM.load_state_dict(checkpoint['Discriminator'])
    genG_optimizer.load_state_dict(checkpoint['G_optimizer_state_dict'])
    discriM_optimizer.load_state_dict(checkpoint['D_optimizer_state_dict'])
    print(f"Checkpoint loaded from {model_path}")

# %%
filename="checkpoint.pth.tar"

load_model = load_checkpoint(os.path.join(checkpoint_dir, f"{filename}_{num_epochs}"), G, D, g_optimizer, d_optimizer)
# Out:
# Checkpoint loaded from ./training_checkpoints/checkpoint.pth.tar_300

# %% [markdown]
# **Step 6: Re-train the GAN model to see if you can improve.**

# %%
# %%time

num_epochs = 50
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(301, 350):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [301/50], Step [200/600], d_loss: 0.9306, g_loss: 1.3629, D(x): 0.68, D(G(z)): 0.32
# Epoch [301/50], Step [400/600], d_loss: 0.7875, g_loss: 1.6698, D(x): 0.77, D(G(z)): 0.31
# Epoch [301/50], Step [600/600], d_loss: 1.1072, g_loss: 1.3845, D(x): 0.60, D(G(z)): 0.32
# Saving fake_images-0302.png
# Epoch [302/50], Step [200/600], d_loss: 0.8066, g_loss: 1.6660, D(x): 0.71, D(G(z)): 0.28
# Epoch [302/50], Step [400/600], d_loss: 0.9428, g_loss: 1.4607, D(x): 0.69, D(G(z)): 0.35
# Epoch [302/50], Step [600/600], d_loss: 1.0435, g_loss: 1.3813, D(x): 0.62, D(G(z)): 0.31
# Saving fake_images-0303.png
# Epoch [303/50], Step [200/600], d_loss: 0.8318, g_loss: 1.6802, D(x): 0.72, D(G(z)): 0.32
# Epoch [303/50], Step [400/600], d_loss: 1.3860, g_loss: 1.0470, D(x): 0.57, D(G(z)): 0.41
# Epoch [303/50], Step [600/600], d_loss: 0.8658, g_loss: 1.4085, D(x): 0.75, D(G(z)): 0.34
# Saving fake_images-0304.png
# Epoch [304/50], Step [200/600], d_loss: 1.1882, g_loss: 1.3078, D(x): 0.61, D(G(z)): 0.35
# Epoch [304/50], Step [400/600], d_loss: 1.5160, g_loss: 1.1884, D(x): 0.53, D(G(z)): 0.42
# Epoch [304/50], Step [600/600], d_loss: 0.9073, g_loss: 1.6270, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0305.png
# Epoch [305/50], Step [200/600], d_loss: 1.0221, g_loss: 1.3387, D(x): 0.66, D(G(z)): 0.36
# Epoch [305/50], Step [400/600], d_loss: 0.9458, g_loss: 1.1970, D(x): 0.68, D(G(z)): 0.33
# Epoch [305/50], Step [600/600], d_loss: 0.6729, g_loss: 1.9980, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0306.png
# Epoch [306/50], Step [200/600], d_loss: 0.8379, g_loss: 1.5909, D(x): 0.74, D(G(z)): 0.32
# Epoch [306/50], Step [400/600], d_loss: 0.8575, g_loss: 1.4336, D(x): 0.70, D(G(z)): 0.29
# Epoch [306/50], Step [600/600], d_loss: 1.1135, g_loss: 1.1518, D(x): 0.64, D(G(z)): 0.39
# Saving fake_images-0307.png
# Epoch [307/50], Step [200/600], d_loss: 0.8924, g_loss: 1.4426, D(x): 0.75, D(G(z)): 0.38
# Epoch [307/50], Step [400/600], d_loss: 0.8028, g_loss: 1.5069, D(x): 0.75, D(G(z)): 0.32
# Epoch [307/50], Step [600/600], d_loss: 0.9636, g_loss: 1.7284, D(x): 0.63, D(G(z)): 0.24
# Saving fake_images-0308.png
# Epoch [308/50], Step [200/600], d_loss: 0.9972, g_loss: 1.2201, D(x): 0.67, D(G(z)): 0.35
# Epoch [308/50], Step [400/600], d_loss: 1.5098, g_loss: 1.3684, D(x): 0.56, D(G(z)): 0.41
# Epoch [308/50], Step [600/600], d_loss: 1.0593, g_loss: 1.5107, D(x): 0.70, D(G(z)): 0.37
# Saving fake_images-0309.png
# Epoch [309/50], Step [200/600], d_loss: 0.9548, g_loss: 1.8623, D(x): 0.68, D(G(z)): 0.32
# Epoch [309/50], Step [400/600], d_loss: 0.9837, g_loss: 1.3527, D(x): 0.66, D(G(z)): 0.34
# Epoch [309/50], Step [600/600], d_loss: 0.9346, g_loss: 1.2780, D(x): 0.74, D(G(z)): 0.38
# Saving fake_images-0310.png
# Epoch [310/50], Step [200/600], d_loss: 0.8373, g_loss: 1.4441, D(x): 0.68, D(G(z)): 0.27
# Epoch [310/50], Step [400/600], d_loss: 1.2220, g_loss: 1.1954, D(x): 0.61, D(G(z)): 0.38
# Epoch [310/50], Step [600/600], d_loss: 0.9059, g_loss: 1.6230, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0311.png
# Epoch [311/50], Step [200/600], d_loss: 0.9108, g_loss: 1.3371, D(x): 0.70, D(G(z)): 0.35
# Epoch [311/50], Step [400/600], d_loss: 1.0497, g_loss: 1.7759, D(x): 0.65, D(G(z)): 0.31
# Epoch [311/50], Step [600/600], d_loss: 1.1587, g_loss: 1.4399, D(x): 0.59, D(G(z)): 0.33
# Saving fake_images-0312.png
# Epoch [312/50], Step [200/600], d_loss: 0.6366, g_loss: 1.9455, D(x): 0.76, D(G(z)): 0.21
# Epoch [312/50], Step [400/600], d_loss: 1.2026, g_loss: 1.2248, D(x): 0.68, D(G(z)): 0.40
# Epoch [312/50], Step [600/600], d_loss: 1.0857, g_loss: 1.3446, D(x): 0.71, D(G(z)): 0.39
# Saving fake_images-0313.png
# Epoch [313/50], Step [200/600], d_loss: 0.8347, g_loss: 1.6368, D(x): 0.72, D(G(z)): 0.29
# Epoch [313/50], Step [400/600], d_loss: 0.7480, g_loss: 1.4807, D(x): 0.73, D(G(z)): 0.26
# Epoch [313/50], Step [600/600], d_loss: 1.1747, g_loss: 1.2143, D(x): 0.60, D(G(z)): 0.36
# Saving fake_images-0314.png
# Epoch [314/50], Step [200/600], d_loss: 1.0014, g_loss: 1.3881, D(x): 0.70, D(G(z)): 0.37
# Epoch [314/50], Step [400/600], d_loss: 1.0588, g_loss: 1.5652, D(x): 0.68, D(G(z)): 0.37
# Epoch [314/50], Step [600/600], d_loss: 0.8897, g_loss: 1.4860, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0315.png
# Epoch [315/50], Step [200/600], d_loss: 1.0374, g_loss: 1.7269, D(x): 0.63, D(G(z)): 0.28
# Epoch [315/50], Step [400/600], d_loss: 1.2034, g_loss: 1.2202, D(x): 0.58, D(G(z)): 0.34
# Epoch [315/50], Step [600/600], d_loss: 0.8834, g_loss: 1.2233, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0316.png
# Epoch [316/50], Step [200/600], d_loss: 0.9265, g_loss: 1.6172, D(x): 0.71, D(G(z)): 0.33
# Epoch [316/50], Step [400/600], d_loss: 1.0966, g_loss: 1.6347, D(x): 0.58, D(G(z)): 0.26
# Epoch [316/50], Step [600/600], d_loss: 1.0737, g_loss: 1.1207, D(x): 0.71, D(G(z)): 0.40
# Saving fake_images-0317.png
# Epoch [317/50], Step [200/600], d_loss: 0.9151, g_loss: 1.3757, D(x): 0.69, D(G(z)): 0.31
# Epoch [317/50], Step [400/600], d_loss: 0.8825, g_loss: 1.7614, D(x): 0.65, D(G(z)): 0.26
# Epoch [317/50], Step [600/600], d_loss: 1.0361, g_loss: 1.3499, D(x): 0.63, D(G(z)): 0.31
# Saving fake_images-0318.png
# Epoch [318/50], Step [200/600], d_loss: 1.1896, g_loss: 1.2453, D(x): 0.58, D(G(z)): 0.32
# Epoch [318/50], Step [400/600], d_loss: 0.9678, g_loss: 1.3330, D(x): 0.66, D(G(z)): 0.31
# Epoch [318/50], Step [600/600], d_loss: 0.8415, g_loss: 1.6653, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0319.png
# Epoch [319/50], Step [200/600], d_loss: 1.0366, g_loss: 1.2621, D(x): 0.65, D(G(z)): 0.36
# Epoch [319/50], Step [400/600], d_loss: 0.7998, g_loss: 1.9179, D(x): 0.73, D(G(z)): 0.28
# Epoch [319/50], Step [600/600], d_loss: 1.0201, g_loss: 1.0796, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0320.png
# Epoch [320/50], Step [200/600], d_loss: 0.9299, g_loss: 1.2540, D(x): 0.72, D(G(z)): 0.32
# Epoch [320/50], Step [400/600], d_loss: 0.7660, g_loss: 1.9497, D(x): 0.66, D(G(z)): 0.21
# Epoch [320/50], Step [600/600], d_loss: 1.1150, g_loss: 1.2025, D(x): 0.69, D(G(z)): 0.39
# Saving fake_images-0321.png
# Epoch [321/50], Step [200/600], d_loss: 0.7408, g_loss: 1.4623, D(x): 0.78, D(G(z)): 0.31
# Epoch [321/50], Step [400/600], d_loss: 0.9791, g_loss: 1.3500, D(x): 0.69, D(G(z)): 0.35
# Epoch [321/50], Step [600/600], d_loss: 1.0191, g_loss: 1.4098, D(x): 0.66, D(G(z)): 0.33
# Saving fake_images-0322.png
# Epoch [322/50], Step [200/600], d_loss: 0.8576, g_loss: 1.4443, D(x): 0.70, D(G(z)): 0.28
# Epoch [322/50], Step [400/600], d_loss: 0.7379, g_loss: 1.6147, D(x): 0.73, D(G(z)): 0.24
# Epoch [322/50], Step [600/600], d_loss: 1.1358, g_loss: 1.4932, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0323.png
# Epoch [323/50], Step [200/600], d_loss: 0.6417, g_loss: 1.8890, D(x): 0.77, D(G(z)): 0.24
# Epoch [323/50], Step [400/600], d_loss: 1.0498, g_loss: 1.3971, D(x): 0.66, D(G(z)): 0.33
# Epoch [323/50], Step [600/600], d_loss: 1.0607, g_loss: 1.4514, D(x): 0.64, D(G(z)): 0.33
# Saving fake_images-0324.png
# Epoch [324/50], Step [200/600], d_loss: 0.9875, g_loss: 1.3559, D(x): 0.68, D(G(z)): 0.33
# Epoch [324/50], Step [400/600], d_loss: 0.7964, g_loss: 1.5498, D(x): 0.70, D(G(z)): 0.27
# Epoch [324/50], Step [600/600], d_loss: 1.1745, g_loss: 1.2024, D(x): 0.62, D(G(z)): 0.39
# Saving fake_images-0325.png
# Epoch [325/50], Step [200/600], d_loss: 0.7945, g_loss: 1.5566, D(x): 0.71, D(G(z)): 0.28
# Epoch [325/50], Step [400/600], d_loss: 1.0672, g_loss: 1.2731, D(x): 0.62, D(G(z)): 0.35
# Epoch [325/50], Step [600/600], d_loss: 0.9416, g_loss: 1.3692, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0326.png
# Epoch [326/50], Step [200/600], d_loss: 1.1719, g_loss: 1.2193, D(x): 0.62, D(G(z)): 0.36
# Epoch [326/50], Step [400/600], d_loss: 0.8879, g_loss: 1.7004, D(x): 0.66, D(G(z)): 0.26
# Epoch [326/50], Step [600/600], d_loss: 0.9439, g_loss: 1.3219, D(x): 0.73, D(G(z)): 0.36
# Saving fake_images-0327.png
# Epoch [327/50], Step [200/600], d_loss: 1.0068, g_loss: 1.3573, D(x): 0.69, D(G(z)): 0.34
# Epoch [327/50], Step [400/600], d_loss: 1.0662, g_loss: 1.3652, D(x): 0.66, D(G(z)): 0.37
# Epoch [327/50], Step [600/600], d_loss: 1.1226, g_loss: 1.2314, D(x): 0.63, D(G(z)): 0.35
# Saving fake_images-0328.png
# Epoch [328/50], Step [200/600], d_loss: 0.8527, g_loss: 1.2558, D(x): 0.71, D(G(z)): 0.31
# Epoch [328/50], Step [400/600], d_loss: 1.2043, g_loss: 1.2779, D(x): 0.64, D(G(z)): 0.41
# Epoch [328/50], Step [600/600], d_loss: 1.0875, g_loss: 1.6324, D(x): 0.65, D(G(z)): 0.35
# Saving fake_images-0329.png
# Epoch [329/50], Step [200/600], d_loss: 0.8518, g_loss: 1.6586, D(x): 0.78, D(G(z)): 0.36
# Epoch [329/50], Step [400/600], d_loss: 0.8703, g_loss: 1.5129, D(x): 0.68, D(G(z)): 0.29
# Epoch [329/50], Step [600/600], d_loss: 1.0421, g_loss: 1.6469, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0330.png
# Epoch [330/50], Step [200/600], d_loss: 0.8955, g_loss: 1.4148, D(x): 0.72, D(G(z)): 0.36
# Epoch [330/50], Step [400/600], d_loss: 0.7495, g_loss: 1.8140, D(x): 0.73, D(G(z)): 0.27
# Epoch [330/50], Step [600/600], d_loss: 1.2412, g_loss: 1.1246, D(x): 0.59, D(G(z)): 0.38
# Saving fake_images-0331.png
# Epoch [331/50], Step [200/600], d_loss: 0.9568, g_loss: 1.4022, D(x): 0.70, D(G(z)): 0.34
# Epoch [331/50], Step [400/600], d_loss: 1.2834, g_loss: 1.2531, D(x): 0.59, D(G(z)): 0.39
# Epoch [331/50], Step [600/600], d_loss: 0.9161, g_loss: 1.9666, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0332.png
# Epoch [332/50], Step [200/600], d_loss: 1.0647, g_loss: 1.6019, D(x): 0.69, D(G(z)): 0.35
# Epoch [332/50], Step [400/600], d_loss: 1.1740, g_loss: 1.2662, D(x): 0.63, D(G(z)): 0.38
# Epoch [332/50], Step [600/600], d_loss: 0.8162, g_loss: 1.2085, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0333.png
# Epoch [333/50], Step [200/600], d_loss: 1.1449, g_loss: 1.3213, D(x): 0.65, D(G(z)): 0.40
# Epoch [333/50], Step [400/600], d_loss: 0.7905, g_loss: 1.3701, D(x): 0.77, D(G(z)): 0.32
# Epoch [333/50], Step [600/600], d_loss: 1.1577, g_loss: 1.0623, D(x): 0.65, D(G(z)): 0.40
# Saving fake_images-0334.png
# Epoch [334/50], Step [200/600], d_loss: 1.1507, g_loss: 1.1945, D(x): 0.64, D(G(z)): 0.40
# Epoch [334/50], Step [400/600], d_loss: 1.0020, g_loss: 1.4031, D(x): 0.65, D(G(z)): 0.32
# Epoch [334/50], Step [600/600], d_loss: 0.9455, g_loss: 1.5720, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0335.png
# Epoch [335/50], Step [200/600], d_loss: 1.3999, g_loss: 1.3380, D(x): 0.52, D(G(z)): 0.34
# Epoch [335/50], Step [400/600], d_loss: 0.9957, g_loss: 1.5361, D(x): 0.70, D(G(z)): 0.34
# Epoch [335/50], Step [600/600], d_loss: 1.2123, g_loss: 1.3713, D(x): 0.70, D(G(z)): 0.41
# Saving fake_images-0336.png
# Epoch [336/50], Step [200/600], d_loss: 1.0638, g_loss: 1.5624, D(x): 0.64, D(G(z)): 0.32
# Epoch [336/50], Step [400/600], d_loss: 1.1860, g_loss: 1.2984, D(x): 0.67, D(G(z)): 0.43
# Epoch [336/50], Step [600/600], d_loss: 0.9886, g_loss: 1.4255, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0337.png
# Epoch [337/50], Step [200/600], d_loss: 1.0825, g_loss: 1.5619, D(x): 0.61, D(G(z)): 0.31
# Epoch [337/50], Step [400/600], d_loss: 0.9331, g_loss: 1.3562, D(x): 0.71, D(G(z)): 0.33
# Epoch [337/50], Step [600/600], d_loss: 0.9249, g_loss: 1.6180, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0338.png
# Epoch [338/50], Step [200/600], d_loss: 1.3146, g_loss: 1.1202, D(x): 0.59, D(G(z)): 0.40
# Epoch [338/50], Step [400/600], d_loss: 0.9340, g_loss: 1.4415, D(x): 0.70, D(G(z)): 0.34
# Epoch [338/50], Step [600/600], d_loss: 0.9556, g_loss: 1.3110, D(x): 0.73, D(G(z)): 0.38
# Saving fake_images-0339.png
# Epoch [339/50], Step [200/600], d_loss: 1.2652, g_loss: 1.2676, D(x): 0.69, D(G(z)): 0.46
# Epoch [339/50], Step [400/600], d_loss: 0.8254, g_loss: 1.5634, D(x): 0.70, D(G(z)): 0.29
# Epoch [339/50], Step [600/600], d_loss: 1.0256, g_loss: 1.2661, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0340.png
# Epoch [340/50], Step [200/600], d_loss: 0.9037, g_loss: 1.4918, D(x): 0.69, D(G(z)): 0.30
# Epoch [340/50], Step [400/600], d_loss: 0.8621, g_loss: 1.1949, D(x): 0.74, D(G(z)): 0.34
# Epoch [340/50], Step [600/600], d_loss: 0.9719, g_loss: 1.1886, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0341.png
# Epoch [341/50], Step [200/600], d_loss: 1.1187, g_loss: 1.2215, D(x): 0.67, D(G(z)): 0.42
# Epoch [341/50], Step [400/600], d_loss: 1.0555, g_loss: 1.3367, D(x): 0.62, D(G(z)): 0.31
# Epoch [341/50], Step [600/600], d_loss: 0.9943, g_loss: 1.6314, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0342.png
# Epoch [342/50], Step [200/600], d_loss: 0.9415, g_loss: 1.2538, D(x): 0.72, D(G(z)): 0.37
# Epoch [342/50], Step [400/600], d_loss: 1.1347, g_loss: 1.5859, D(x): 0.57, D(G(z)): 0.32
# Epoch [342/50], Step [600/600], d_loss: 0.7386, g_loss: 1.6192, D(x): 0.79, D(G(z)): 0.32
# Saving fake_images-0343.png
# Epoch [343/50], Step [200/600], d_loss: 0.9228, g_loss: 1.6905, D(x): 0.67, D(G(z)): 0.30
# Epoch [343/50], Step [400/600], d_loss: 0.7096, g_loss: 1.8401, D(x): 0.76, D(G(z)): 0.27
# Epoch [343/50], Step [600/600], d_loss: 1.1889, g_loss: 1.6145, D(x): 0.61, D(G(z)): 0.32
# Saving fake_images-0344.png
# Epoch [344/50], Step [200/600], d_loss: 1.1394, g_loss: 1.2366, D(x): 0.62, D(G(z)): 0.33
# Epoch [344/50], Step [400/600], d_loss: 1.4079, g_loss: 1.1872, D(x): 0.58, D(G(z)): 0.42
# Epoch [344/50], Step [600/600], d_loss: 1.1243, g_loss: 1.3431, D(x): 0.63, D(G(z)): 0.32
# Saving fake_images-0345.png
# Epoch [345/50], Step [200/600], d_loss: 0.8413, g_loss: 1.5106, D(x): 0.70, D(G(z)): 0.27
# Epoch [345/50], Step [400/600], d_loss: 1.1760, g_loss: 1.3723, D(x): 0.63, D(G(z)): 0.38
# Epoch [345/50], Step [600/600], d_loss: 0.9586, g_loss: 1.3385, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0346.png
# Epoch [346/50], Step [200/600], d_loss: 0.9933, g_loss: 1.6904, D(x): 0.62, D(G(z)): 0.28
# Epoch [346/50], Step [400/600], d_loss: 0.8855, g_loss: 1.5798, D(x): 0.68, D(G(z)): 0.27
# Epoch [346/50], Step [600/600], d_loss: 1.2424, g_loss: 1.6310, D(x): 0.55, D(G(z)): 0.28
# Saving fake_images-0347.png
# Epoch [347/50], Step [200/600], d_loss: 0.6682, g_loss: 1.5622, D(x): 0.73, D(G(z)): 0.22
# Epoch [347/50], Step [400/600], d_loss: 0.9872, g_loss: 1.5199, D(x): 0.64, D(G(z)): 0.29
# Epoch [347/50], Step [600/600], d_loss: 1.0129, g_loss: 1.2102, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0348.png
# Epoch [348/50], Step [200/600], d_loss: 1.1676, g_loss: 1.3942, D(x): 0.62, D(G(z)): 0.34
# Epoch [348/50], Step [400/600], d_loss: 0.7987, g_loss: 1.4760, D(x): 0.73, D(G(z)): 0.29
# Epoch [348/50], Step [600/600], d_loss: 0.8719, g_loss: 1.4483, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0349.png
# Epoch [349/50], Step [200/600], d_loss: 0.8936, g_loss: 1.3476, D(x): 0.71, D(G(z)): 0.31
# Epoch [349/50], Step [400/600], d_loss: 0.6023, g_loss: 2.2048, D(x): 0.77, D(G(z)): 0.21
# Epoch [349/50], Step [600/600], d_loss: 1.5324, g_loss: 1.1849, D(x): 0.62, D(G(z)): 0.51
# Saving fake_images-0350.png
# CPU times: user 28min 38s, sys: 6.98 s, total: 28min 45s
# Wall time: 29min 6s

# %%
Image('./samples_chk/fake_images-0300.png')

# %%
Image('./samples_chk/fake_images-0350.png')

# %%
# Show plot of real and fake scores

plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# **Step 7: Save the model weights without using checkpoints.**

# %%
# specify a path to save models

save_directory = './saved_models'

# Check if the directory exists, and if not, create it
if not os.path.exists(save_directory):
    os.makedirs(save_directory)

# Save weights without check point
torch.save(G.state_dict, os.path.join(save_directory, 'G_weights.pth'))
torch.save(D.state_dict, os.path.join(save_directory, 'D_weights.pth'))

# %% [markdown]
# **Step 8: Load the model weights without using checkpoints.**

# %%
# Load the models again

genG = G.to(device)
discriM = D.to(device)

# Load generator and discriminator weights
genG_weights = torch.load(os.path.join(save_directory, 'G_weights.pth'))
discriM_weights = torch.load(os.path.join(save_directory, 'D_weights.pth'))
