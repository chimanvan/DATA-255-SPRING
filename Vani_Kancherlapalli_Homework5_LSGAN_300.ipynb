# %%
# Mount to Google drive
from google.colab import drive
drive.mount('/content/drive/')

# Navigate to necessary folder
# %cd '/content/drive/My Drive/Data 255 Spring 2024/Google Colab/Homework5'
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/Data 255 Spring 2024/Google Colab/Homework5

# %% [markdown]
# **Step1. Load the Fashion MNIST dataset and replace the original dataset used in the demo.**

# %%
# Import necessary libraries

import torch
import torchvision
import torch.nn as nn
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
import torchvision.utils as vutils
# Predefined fuction to save images
from torchvision.utils import save_image

import matplotlib.pyplot as plt
# %matplotlib inline
import os
from IPython.display import Image

# %%
# Device configuration,GPU or the CPU is checked in this block

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
#Load the dataset, train dataset, and transform to tensor, data preprocessing task

mnist = FashionMNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %%
#Viewing the data

img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %%
# Viewing the images we would like to de normalize it
# Currently the image is normalized to [-,1,1[] and we convert
# back to [0,1[] to show the image. Tensor x on adding one shifts from
# [-1,1] to [0,2] and divding by 2 give [0,1]. Clamp makes sure
# values outside of [0,1] are set to 0 or 1

def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
# Set variables

# Size of each batch
batch_size = 100
# image size 28*28
image_size = 784

hidden_size = 256
# Dimentionality of the latent space, larger latent space
# captures more intricate patterns, but also requires more resources
latent_size = 64

# %%
#To ensure that the data is loaded in batches during training we are using a DataLoader.

data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
# Plot some training images
import numpy as np

real_batch = next(iter(data_loader))
plt.figure(figsize=(5, 5))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
# Create a directory to save the real image

sample_dir = 'samples_chk_mse'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
# Save real image

for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

# Show the real image - which is the first batch of 100 images
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# **Step2. Train the GAN model to produce images in this new domain.**

# %% [markdown]
# Define the **Discriminator**

# %%
#Define a pretty simple Disriminator network which has:
# 1. Linear layer which takes in an input of image_size as 784 and hidden size 256
# 2. The output of the linear layer is passed through a ReLU activation function
# 3. The result of the activation function is then passed through a Linear layer which takes in 256 input and produces 256 outputs
# 4. This result is again passed through a leaky relu layer.
# 5. Finally the output is passed through a Linear layer and the result is passed through the sigmoid function.

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# Define the **Generator**

# %%
#Define a pretty simple Generator network which has:
# 1. Linear layer which takes in an input of image_size as 64 and hidden size 256
# 2. The output of the linear layer is passed through a ReLU activation function
# 3. The result of the activation function is then passed through a Linear layer which takes in 256 input and produces 256 outputs
# 4. This result is again passed through a leaky relu layer.
# 5. Finally the output is passed through a Linear layer and the result is passed through the tanh() function.

G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# **Step3. Attempt to save and display at least 3 samples produced from your GAN model. Describe and discuss any difficulties faced in this process.**

# %%
y = G(torch.randn(3, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %%
plt.imshow(gen_imgs[2], cmap='gray');

# %%
D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %% [markdown]
# Training the Discriminator starts with defining the loss and optimizier. The Discriminator need to identify between real and fake images, it is binary classification and hence use the Binary class entropy for the loss calculation. Using the Adam optimizer to perform gradient descent.
#
# The discriminator will class all images from the data_loader dataset which is the FASHIONMNIST dataset as real images and the images from Generator as fake images. We find the loss for the images from the MNIST dataset by setting the labels to be compared with in the loss function as 1 and vice versa for the images generated by the generator. After we have calculated the loss for both the real and fake set of images, we add the two losses as the net loss for the discriminator. You can also observe that only the gradients of the discriminator is being calculated and not that of the generator as in this piece of code we are only training the discriminator.

# %%
# Define the loss and optimizer
# Define MSE loss
criterion = nn.MSELoss()
#nn.BCELoss()

# Optimizer for Discriminator
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
#Training the discriminator

def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # So essentially, you use the given set of real images and feed it to the discriminator and train to understand the pattern of the real images.
    # Then, you generate a bunch of fake images and then feed them to the discriminator to train them to understand the pattern of the fake images.

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Training the Generator. A batch of images are generated by the Generator. These images are passed to the Discriminator with label 1 saying they are the real images. This will calculate how far the real images are from the fake ones, calculate the loss.
#
# At the end of the function we see that the weights of the Generator are updated but the weights of the Discriminator stay the same.

# %%
# Optimizer for the Generator

g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %%
# Create a directory to save the intermediate pics the Generator has created
# Define sample vector

sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# %%
# Before training

save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0183, g_loss: 0.8841, D(x): 0.96, D(G(z)): 0.10
# Epoch [0/300], Step [400/600], d_loss: 0.0064, g_loss: 0.9453, D(x): 0.99, D(G(z)): 0.06
# Epoch [0/300], Step [600/600], d_loss: 0.0133, g_loss: 0.9373, D(x): 0.97, D(G(z)): 0.08
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0014, g_loss: 0.9741, D(x): 1.00, D(G(z)): 0.02
# Epoch [1/300], Step [400/600], d_loss: 0.0043, g_loss: 0.9724, D(x): 1.00, D(G(z)): 0.03
# Epoch [1/300], Step [600/600], d_loss: 0.0055, g_loss: 0.9700, D(x): 0.98, D(G(z)): 0.02
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.0012, g_loss: 0.9757, D(x): 1.00, D(G(z)): 0.01
# Epoch [2/300], Step [400/600], d_loss: 0.0032, g_loss: 0.9881, D(x): 1.00, D(G(z)): 0.02
# Epoch [2/300], Step [600/600], d_loss: 0.0298, g_loss: 0.9988, D(x): 0.95, D(G(z)): 0.00
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.0074, g_loss: 0.9938, D(x): 0.98, D(G(z)): 0.01
# Epoch [3/300], Step [400/600], d_loss: 0.0129, g_loss: 0.9101, D(x): 0.99, D(G(z)): 0.07
# Epoch [3/300], Step [600/600], d_loss: 0.0328, g_loss: 0.9931, D(x): 0.95, D(G(z)): 0.01
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.0368, g_loss: 0.9985, D(x): 0.95, D(G(z)): 0.00
# Epoch [4/300], Step [400/600], d_loss: 0.0284, g_loss: 0.9923, D(x): 0.96, D(G(z)): 0.01
# Epoch [4/300], Step [600/600], d_loss: 0.0889, g_loss: 0.8877, D(x): 0.96, D(G(z)): 0.12
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.0198, g_loss: 0.9432, D(x): 0.96, D(G(z)): 0.02
# Epoch [5/300], Step [400/600], d_loss: 0.0255, g_loss: 0.9896, D(x): 0.96, D(G(z)): 0.01
# Epoch [5/300], Step [600/600], d_loss: 0.0117, g_loss: 0.9514, D(x): 0.99, D(G(z)): 0.04
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.1458, g_loss: 0.9321, D(x): 0.87, D(G(z)): 0.07
# Epoch [6/300], Step [400/600], d_loss: 0.0464, g_loss: 0.9683, D(x): 0.95, D(G(z)): 0.05
# Epoch [6/300], Step [600/600], d_loss: 0.0742, g_loss: 0.9515, D(x): 0.92, D(G(z)): 0.06
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.0344, g_loss: 0.9740, D(x): 0.94, D(G(z)): 0.05
# Epoch [7/300], Step [400/600], d_loss: 0.0695, g_loss: 0.9391, D(x): 0.95, D(G(z)): 0.12
# Epoch [7/300], Step [600/600], d_loss: 0.0422, g_loss: 0.9863, D(x): 0.94, D(G(z)): 0.03
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.0416, g_loss: 0.9928, D(x): 0.93, D(G(z)): 0.01
# Epoch [8/300], Step [400/600], d_loss: 0.0813, g_loss: 0.9484, D(x): 0.91, D(G(z)): 0.04
# Epoch [8/300], Step [600/600], d_loss: 0.0817, g_loss: 0.9574, D(x): 0.92, D(G(z)): 0.09
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.1268, g_loss: 0.9443, D(x): 0.83, D(G(z)): 0.06
# Epoch [9/300], Step [400/600], d_loss: 0.0698, g_loss: 0.9332, D(x): 0.91, D(G(z)): 0.06
# Epoch [9/300], Step [600/600], d_loss: 0.1367, g_loss: 0.9236, D(x): 0.84, D(G(z)): 0.05
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.0717, g_loss: 0.9574, D(x): 0.94, D(G(z)): 0.11
# Epoch [10/300], Step [400/600], d_loss: 0.0588, g_loss: 0.9668, D(x): 0.89, D(G(z)): 0.03
# Epoch [10/300], Step [600/600], d_loss: 0.0567, g_loss: 0.9241, D(x): 0.91, D(G(z)): 0.05
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.1292, g_loss: 0.9387, D(x): 0.90, D(G(z)): 0.16
# Epoch [11/300], Step [400/600], d_loss: 0.0884, g_loss: 0.8693, D(x): 0.91, D(G(z)): 0.10
# Epoch [11/300], Step [600/600], d_loss: 0.0775, g_loss: 0.9742, D(x): 0.87, D(G(z)): 0.03
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.0669, g_loss: 0.9427, D(x): 0.89, D(G(z)): 0.06
# Epoch [12/300], Step [400/600], d_loss: 0.0817, g_loss: 0.9414, D(x): 0.92, D(G(z)): 0.07
# Epoch [12/300], Step [600/600], d_loss: 0.0992, g_loss: 0.9253, D(x): 0.91, D(G(z)): 0.11
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.0418, g_loss: 0.9694, D(x): 0.95, D(G(z)): 0.06
# Epoch [13/300], Step [400/600], d_loss: 0.1460, g_loss: 0.9334, D(x): 0.80, D(G(z)): 0.04
# Epoch [13/300], Step [600/600], d_loss: 0.2092, g_loss: 0.8537, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.1070, g_loss: 0.7988, D(x): 0.87, D(G(z)): 0.09
# Epoch [14/300], Step [400/600], d_loss: 0.1775, g_loss: 0.9023, D(x): 0.85, D(G(z)): 0.16
# Epoch [14/300], Step [600/600], d_loss: 0.1183, g_loss: 0.9366, D(x): 0.94, D(G(z)): 0.20
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.1079, g_loss: 0.8649, D(x): 0.92, D(G(z)): 0.15
# Epoch [15/300], Step [400/600], d_loss: 0.1707, g_loss: 0.8685, D(x): 0.84, D(G(z)): 0.17
# Epoch [15/300], Step [600/600], d_loss: 0.1604, g_loss: 0.9027, D(x): 0.80, D(G(z)): 0.10
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.1228, g_loss: 0.9320, D(x): 0.84, D(G(z)): 0.04
# Epoch [16/300], Step [400/600], d_loss: 0.1254, g_loss: 0.8318, D(x): 0.92, D(G(z)): 0.17
# Epoch [16/300], Step [600/600], d_loss: 0.2320, g_loss: 0.7126, D(x): 0.81, D(G(z)): 0.19
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.1011, g_loss: 0.8922, D(x): 0.93, D(G(z)): 0.14
# Epoch [17/300], Step [400/600], d_loss: 0.1834, g_loss: 0.8365, D(x): 0.83, D(G(z)): 0.16
# Epoch [17/300], Step [600/600], d_loss: 0.1155, g_loss: 0.8657, D(x): 0.91, D(G(z)): 0.15
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.3247, g_loss: 0.8227, D(x): 0.64, D(G(z)): 0.12
# Epoch [18/300], Step [400/600], d_loss: 0.0821, g_loss: 0.8812, D(x): 0.89, D(G(z)): 0.06
# Epoch [18/300], Step [600/600], d_loss: 0.2664, g_loss: 0.8961, D(x): 0.76, D(G(z)): 0.17
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.1868, g_loss: 0.7416, D(x): 0.81, D(G(z)): 0.15
# Epoch [19/300], Step [400/600], d_loss: 0.1703, g_loss: 0.8381, D(x): 0.81, D(G(z)): 0.12
# Epoch [19/300], Step [600/600], d_loss: 0.1102, g_loss: 0.8724, D(x): 0.85, D(G(z)): 0.07
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.1243, g_loss: 0.7804, D(x): 0.86, D(G(z)): 0.09
# Epoch [20/300], Step [400/600], d_loss: 0.0499, g_loss: 0.8671, D(x): 0.90, D(G(z)): 0.06
# Epoch [20/300], Step [600/600], d_loss: 0.1569, g_loss: 0.8520, D(x): 0.80, D(G(z)): 0.10
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.1391, g_loss: 0.8444, D(x): 0.85, D(G(z)): 0.11
# Epoch [21/300], Step [400/600], d_loss: 0.1560, g_loss: 0.8134, D(x): 0.83, D(G(z)): 0.14
# Epoch [21/300], Step [600/600], d_loss: 0.1616, g_loss: 0.8336, D(x): 0.82, D(G(z)): 0.13
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.1869, g_loss: 0.8311, D(x): 0.77, D(G(z)): 0.15
# Epoch [22/300], Step [400/600], d_loss: 0.1197, g_loss: 0.7734, D(x): 0.90, D(G(z)): 0.17
# Epoch [22/300], Step [600/600], d_loss: 0.2041, g_loss: 0.7900, D(x): 0.76, D(G(z)): 0.13
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.1603, g_loss: 0.8240, D(x): 0.81, D(G(z)): 0.09
# Epoch [23/300], Step [400/600], d_loss: 0.1346, g_loss: 0.8498, D(x): 0.88, D(G(z)): 0.17
# Epoch [23/300], Step [600/600], d_loss: 0.1852, g_loss: 0.8198, D(x): 0.78, D(G(z)): 0.14
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.2223, g_loss: 0.6857, D(x): 0.76, D(G(z)): 0.17
# Epoch [24/300], Step [400/600], d_loss: 0.3152, g_loss: 0.8809, D(x): 0.67, D(G(z)): 0.17
# Epoch [24/300], Step [600/600], d_loss: 0.1762, g_loss: 0.7285, D(x): 0.79, D(G(z)): 0.14
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.1655, g_loss: 0.8272, D(x): 0.84, D(G(z)): 0.19
# Epoch [25/300], Step [400/600], d_loss: 0.1709, g_loss: 0.8865, D(x): 0.87, D(G(z)): 0.16
# Epoch [25/300], Step [600/600], d_loss: 0.1583, g_loss: 0.7468, D(x): 0.87, D(G(z)): 0.19
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.2475, g_loss: 0.7706, D(x): 0.82, D(G(z)): 0.26
# Epoch [26/300], Step [400/600], d_loss: 0.1742, g_loss: 0.8565, D(x): 0.78, D(G(z)): 0.10
# Epoch [26/300], Step [600/600], d_loss: 0.1971, g_loss: 0.8234, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.1411, g_loss: 0.7399, D(x): 0.89, D(G(z)): 0.22
# Epoch [27/300], Step [400/600], d_loss: 0.1056, g_loss: 0.7529, D(x): 0.90, D(G(z)): 0.18
# Epoch [27/300], Step [600/600], d_loss: 0.3551, g_loss: 0.6807, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.1214, g_loss: 0.9134, D(x): 0.84, D(G(z)): 0.10
# Epoch [28/300], Step [400/600], d_loss: 0.2604, g_loss: 0.7168, D(x): 0.71, D(G(z)): 0.15
# Epoch [28/300], Step [600/600], d_loss: 0.2326, g_loss: 0.6419, D(x): 0.79, D(G(z)): 0.24
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.1587, g_loss: 0.7442, D(x): 0.81, D(G(z)): 0.15
# Epoch [29/300], Step [400/600], d_loss: 0.1193, g_loss: 0.7936, D(x): 0.85, D(G(z)): 0.13
# Epoch [29/300], Step [600/600], d_loss: 0.1188, g_loss: 0.8447, D(x): 0.84, D(G(z)): 0.10
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.2084, g_loss: 0.8124, D(x): 0.82, D(G(z)): 0.21
# Epoch [30/300], Step [400/600], d_loss: 0.2252, g_loss: 0.7535, D(x): 0.77, D(G(z)): 0.22
# Epoch [30/300], Step [600/600], d_loss: 0.1591, g_loss: 0.7829, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.1764, g_loss: 0.6697, D(x): 0.90, D(G(z)): 0.26
# Epoch [31/300], Step [400/600], d_loss: 0.2236, g_loss: 0.7107, D(x): 0.76, D(G(z)): 0.17
# Epoch [31/300], Step [600/600], d_loss: 0.2217, g_loss: 0.7683, D(x): 0.73, D(G(z)): 0.13
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.2682, g_loss: 0.8053, D(x): 0.70, D(G(z)): 0.16
# Epoch [32/300], Step [400/600], d_loss: 0.2840, g_loss: 0.6846, D(x): 0.73, D(G(z)): 0.24
# Epoch [32/300], Step [600/600], d_loss: 0.2014, g_loss: 0.7592, D(x): 0.85, D(G(z)): 0.23
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.1658, g_loss: 0.7964, D(x): 0.81, D(G(z)): 0.15
# Epoch [33/300], Step [400/600], d_loss: 0.3065, g_loss: 0.6898, D(x): 0.78, D(G(z)): 0.34
# Epoch [33/300], Step [600/600], d_loss: 0.3372, g_loss: 0.7152, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.2003, g_loss: 0.7775, D(x): 0.77, D(G(z)): 0.16
# Epoch [34/300], Step [400/600], d_loss: 0.1917, g_loss: 0.7275, D(x): 0.79, D(G(z)): 0.20
# Epoch [34/300], Step [600/600], d_loss: 0.1904, g_loss: 0.7505, D(x): 0.82, D(G(z)): 0.22
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.1025, g_loss: 0.7935, D(x): 0.92, D(G(z)): 0.17
# Epoch [35/300], Step [400/600], d_loss: 0.1260, g_loss: 0.8902, D(x): 0.83, D(G(z)): 0.14
# Epoch [35/300], Step [600/600], d_loss: 0.1717, g_loss: 0.6970, D(x): 0.84, D(G(z)): 0.20
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.1889, g_loss: 0.7278, D(x): 0.80, D(G(z)): 0.20
# Epoch [36/300], Step [400/600], d_loss: 0.1796, g_loss: 0.8396, D(x): 0.78, D(G(z)): 0.16
# Epoch [36/300], Step [600/600], d_loss: 0.2691, g_loss: 0.7287, D(x): 0.82, D(G(z)): 0.31
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.2257, g_loss: 0.6967, D(x): 0.83, D(G(z)): 0.27
# Epoch [37/300], Step [400/600], d_loss: 0.1967, g_loss: 0.8036, D(x): 0.76, D(G(z)): 0.17
# Epoch [37/300], Step [600/600], d_loss: 0.1370, g_loss: 0.8545, D(x): 0.81, D(G(z)): 0.11
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.2204, g_loss: 0.6687, D(x): 0.79, D(G(z)): 0.23
# Epoch [38/300], Step [400/600], d_loss: 0.2382, g_loss: 0.6783, D(x): 0.80, D(G(z)): 0.24
# Epoch [38/300], Step [600/600], d_loss: 0.1376, g_loss: 0.7451, D(x): 0.87, D(G(z)): 0.23
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.1902, g_loss: 0.7118, D(x): 0.81, D(G(z)): 0.19
# Epoch [39/300], Step [400/600], d_loss: 0.2150, g_loss: 0.7375, D(x): 0.83, D(G(z)): 0.29
# Epoch [39/300], Step [600/600], d_loss: 0.1441, g_loss: 0.8310, D(x): 0.82, D(G(z)): 0.10
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.2499, g_loss: 0.8190, D(x): 0.73, D(G(z)): 0.18
# Epoch [40/300], Step [400/600], d_loss: 0.3316, g_loss: 0.7362, D(x): 0.61, D(G(z)): 0.13
# Epoch [40/300], Step [600/600], d_loss: 0.2188, g_loss: 0.8424, D(x): 0.73, D(G(z)): 0.13
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.1489, g_loss: 0.8281, D(x): 0.83, D(G(z)): 0.17
# Epoch [41/300], Step [400/600], d_loss: 0.2512, g_loss: 0.7181, D(x): 0.79, D(G(z)): 0.27
# Epoch [41/300], Step [600/600], d_loss: 0.1459, g_loss: 0.7026, D(x): 0.87, D(G(z)): 0.20
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.3000, g_loss: 0.5122, D(x): 0.71, D(G(z)): 0.25
# Epoch [42/300], Step [400/600], d_loss: 0.1679, g_loss: 0.8029, D(x): 0.85, D(G(z)): 0.22
# Epoch [42/300], Step [600/600], d_loss: 0.3155, g_loss: 0.7459, D(x): 0.67, D(G(z)): 0.23
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.3735, g_loss: 0.7126, D(x): 0.60, D(G(z)): 0.21
# Epoch [43/300], Step [400/600], d_loss: 0.3215, g_loss: 0.7201, D(x): 0.69, D(G(z)): 0.22
# Epoch [43/300], Step [600/600], d_loss: 0.3861, g_loss: 0.5773, D(x): 0.73, D(G(z)): 0.37
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.2270, g_loss: 0.7149, D(x): 0.81, D(G(z)): 0.28
# Epoch [44/300], Step [400/600], d_loss: 0.2375, g_loss: 0.7109, D(x): 0.83, D(G(z)): 0.30
# Epoch [44/300], Step [600/600], d_loss: 0.1962, g_loss: 0.7634, D(x): 0.75, D(G(z)): 0.16
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.2289, g_loss: 0.6683, D(x): 0.74, D(G(z)): 0.21
# Epoch [45/300], Step [400/600], d_loss: 0.2034, g_loss: 0.7198, D(x): 0.78, D(G(z)): 0.19
# Epoch [45/300], Step [600/600], d_loss: 0.2390, g_loss: 0.7883, D(x): 0.78, D(G(z)): 0.22
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.1741, g_loss: 0.7063, D(x): 0.81, D(G(z)): 0.18
# Epoch [46/300], Step [400/600], d_loss: 0.2328, g_loss: 0.6840, D(x): 0.80, D(G(z)): 0.27
# Epoch [46/300], Step [600/600], d_loss: 0.2581, g_loss: 0.6743, D(x): 0.74, D(G(z)): 0.22
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.2503, g_loss: 0.5930, D(x): 0.70, D(G(z)): 0.20
# Epoch [47/300], Step [400/600], d_loss: 0.3247, g_loss: 0.5474, D(x): 0.71, D(G(z)): 0.30
# Epoch [47/300], Step [600/600], d_loss: 0.2921, g_loss: 0.7686, D(x): 0.77, D(G(z)): 0.29
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.2069, g_loss: 0.6865, D(x): 0.76, D(G(z)): 0.20
# Epoch [48/300], Step [400/600], d_loss: 0.1643, g_loss: 0.6875, D(x): 0.81, D(G(z)): 0.19
# Epoch [48/300], Step [600/600], d_loss: 0.1504, g_loss: 0.8037, D(x): 0.79, D(G(z)): 0.13
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.3108, g_loss: 0.6463, D(x): 0.73, D(G(z)): 0.29
# Epoch [49/300], Step [400/600], d_loss: 0.3143, g_loss: 0.6571, D(x): 0.63, D(G(z)): 0.19
# Epoch [49/300], Step [600/600], d_loss: 0.3541, g_loss: 0.6993, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.2163, g_loss: 0.6565, D(x): 0.82, D(G(z)): 0.23
# Epoch [50/300], Step [400/600], d_loss: 0.2698, g_loss: 0.5857, D(x): 0.71, D(G(z)): 0.23
# Epoch [50/300], Step [600/600], d_loss: 0.2534, g_loss: 0.7654, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.3950, g_loss: 0.6359, D(x): 0.62, D(G(z)): 0.33
# Epoch [51/300], Step [400/600], d_loss: 0.2697, g_loss: 0.6553, D(x): 0.80, D(G(z)): 0.27
# Epoch [51/300], Step [600/600], d_loss: 0.1824, g_loss: 0.7757, D(x): 0.79, D(G(z)): 0.17
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.2305, g_loss: 0.6586, D(x): 0.75, D(G(z)): 0.20
# Epoch [52/300], Step [400/600], d_loss: 0.1614, g_loss: 0.6712, D(x): 0.82, D(G(z)): 0.22
# Epoch [52/300], Step [600/600], d_loss: 0.2805, g_loss: 0.7269, D(x): 0.66, D(G(z)): 0.15
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.2272, g_loss: 0.6897, D(x): 0.75, D(G(z)): 0.23
# Epoch [53/300], Step [400/600], d_loss: 0.3260, g_loss: 0.5094, D(x): 0.77, D(G(z)): 0.38
# Epoch [53/300], Step [600/600], d_loss: 0.1729, g_loss: 0.6708, D(x): 0.86, D(G(z)): 0.24
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.2780, g_loss: 0.6335, D(x): 0.73, D(G(z)): 0.26
# Epoch [54/300], Step [400/600], d_loss: 0.3438, g_loss: 0.6508, D(x): 0.62, D(G(z)): 0.21
# Epoch [54/300], Step [600/600], d_loss: 0.3140, g_loss: 0.6237, D(x): 0.63, D(G(z)): 0.19
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.3360, g_loss: 0.7428, D(x): 0.65, D(G(z)): 0.22
# Epoch [55/300], Step [400/600], d_loss: 0.3196, g_loss: 0.6064, D(x): 0.71, D(G(z)): 0.30
# Epoch [55/300], Step [600/600], d_loss: 0.1921, g_loss: 0.7962, D(x): 0.79, D(G(z)): 0.18
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.2766, g_loss: 0.7901, D(x): 0.68, D(G(z)): 0.19
# Epoch [56/300], Step [400/600], d_loss: 0.2809, g_loss: 0.6941, D(x): 0.67, D(G(z)): 0.19
# Epoch [56/300], Step [600/600], d_loss: 0.2155, g_loss: 0.7116, D(x): 0.79, D(G(z)): 0.24
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.2848, g_loss: 0.7676, D(x): 0.69, D(G(z)): 0.22
# Epoch [57/300], Step [400/600], d_loss: 0.2850, g_loss: 0.7147, D(x): 0.72, D(G(z)): 0.25
# Epoch [57/300], Step [600/600], d_loss: 0.2733, g_loss: 0.7328, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.3149, g_loss: 0.5693, D(x): 0.75, D(G(z)): 0.29
# Epoch [58/300], Step [400/600], d_loss: 0.3771, g_loss: 0.5957, D(x): 0.74, D(G(z)): 0.38
# Epoch [58/300], Step [600/600], d_loss: 0.1862, g_loss: 0.6532, D(x): 0.82, D(G(z)): 0.25
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.3021, g_loss: 0.6569, D(x): 0.68, D(G(z)): 0.28
# Epoch [59/300], Step [400/600], d_loss: 0.2503, g_loss: 0.6927, D(x): 0.71, D(G(z)): 0.22
# Epoch [59/300], Step [600/600], d_loss: 0.1967, g_loss: 0.6929, D(x): 0.78, D(G(z)): 0.24
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.2210, g_loss: 0.6734, D(x): 0.81, D(G(z)): 0.28
# Epoch [60/300], Step [400/600], d_loss: 0.2441, g_loss: 0.6007, D(x): 0.76, D(G(z)): 0.26
# Epoch [60/300], Step [600/600], d_loss: 0.2285, g_loss: 0.7864, D(x): 0.72, D(G(z)): 0.14
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.2683, g_loss: 0.5995, D(x): 0.73, D(G(z)): 0.29
# Epoch [61/300], Step [400/600], d_loss: 0.2450, g_loss: 0.7713, D(x): 0.81, D(G(z)): 0.27
# Epoch [61/300], Step [600/600], d_loss: 0.3075, g_loss: 0.6667, D(x): 0.68, D(G(z)): 0.21
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.2749, g_loss: 0.6855, D(x): 0.72, D(G(z)): 0.24
# Epoch [62/300], Step [400/600], d_loss: 0.3571, g_loss: 0.5996, D(x): 0.64, D(G(z)): 0.29
# Epoch [62/300], Step [600/600], d_loss: 0.3098, g_loss: 0.6050, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.3419, g_loss: 0.5226, D(x): 0.80, D(G(z)): 0.41
# Epoch [63/300], Step [400/600], d_loss: 0.3848, g_loss: 0.5711, D(x): 0.67, D(G(z)): 0.35
# Epoch [63/300], Step [600/600], d_loss: 0.3304, g_loss: 0.5460, D(x): 0.66, D(G(z)): 0.27
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.3783, g_loss: 0.6032, D(x): 0.62, D(G(z)): 0.27
# Epoch [64/300], Step [400/600], d_loss: 0.3151, g_loss: 0.6342, D(x): 0.68, D(G(z)): 0.29
# Epoch [64/300], Step [600/600], d_loss: 0.1749, g_loss: 0.6589, D(x): 0.81, D(G(z)): 0.21
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.2929, g_loss: 0.6066, D(x): 0.75, D(G(z)): 0.31
# Epoch [65/300], Step [400/600], d_loss: 0.2156, g_loss: 0.6198, D(x): 0.78, D(G(z)): 0.26
# Epoch [65/300], Step [600/600], d_loss: 0.3502, g_loss: 0.6371, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.2694, g_loss: 0.6305, D(x): 0.73, D(G(z)): 0.25
# Epoch [66/300], Step [400/600], d_loss: 0.2534, g_loss: 0.7295, D(x): 0.75, D(G(z)): 0.24
# Epoch [66/300], Step [600/600], d_loss: 0.4067, g_loss: 0.5059, D(x): 0.65, D(G(z)): 0.32
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.2377, g_loss: 0.5581, D(x): 0.75, D(G(z)): 0.26
# Epoch [67/300], Step [400/600], d_loss: 0.2938, g_loss: 0.6565, D(x): 0.71, D(G(z)): 0.24
# Epoch [67/300], Step [600/600], d_loss: 0.2597, g_loss: 0.6082, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.1846, g_loss: 0.7514, D(x): 0.73, D(G(z)): 0.16
# Epoch [68/300], Step [400/600], d_loss: 0.2525, g_loss: 0.6560, D(x): 0.72, D(G(z)): 0.25
# Epoch [68/300], Step [600/600], d_loss: 0.3411, g_loss: 0.5023, D(x): 0.63, D(G(z)): 0.25
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.4100, g_loss: 0.5279, D(x): 0.62, D(G(z)): 0.36
# Epoch [69/300], Step [400/600], d_loss: 0.2048, g_loss: 0.7017, D(x): 0.76, D(G(z)): 0.23
# Epoch [69/300], Step [600/600], d_loss: 0.3059, g_loss: 0.6212, D(x): 0.67, D(G(z)): 0.25
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.1946, g_loss: 0.6723, D(x): 0.78, D(G(z)): 0.20
# Epoch [70/300], Step [400/600], d_loss: 0.2960, g_loss: 0.6077, D(x): 0.69, D(G(z)): 0.26
# Epoch [70/300], Step [600/600], d_loss: 0.3201, g_loss: 0.6100, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.3616, g_loss: 0.5651, D(x): 0.71, D(G(z)): 0.36
# Epoch [71/300], Step [400/600], d_loss: 0.3308, g_loss: 0.6036, D(x): 0.67, D(G(z)): 0.30
# Epoch [71/300], Step [600/600], d_loss: 0.3351, g_loss: 0.6546, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.2486, g_loss: 0.6031, D(x): 0.71, D(G(z)): 0.21
# Epoch [72/300], Step [400/600], d_loss: 0.2768, g_loss: 0.5970, D(x): 0.79, D(G(z)): 0.35
# Epoch [72/300], Step [600/600], d_loss: 0.2810, g_loss: 0.6049, D(x): 0.81, D(G(z)): 0.36
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.2053, g_loss: 0.7008, D(x): 0.74, D(G(z)): 0.20
# Epoch [73/300], Step [400/600], d_loss: 0.3425, g_loss: 0.6272, D(x): 0.65, D(G(z)): 0.26
# Epoch [73/300], Step [600/600], d_loss: 0.2427, g_loss: 0.5860, D(x): 0.81, D(G(z)): 0.32
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.3080, g_loss: 0.5302, D(x): 0.73, D(G(z)): 0.32
# Epoch [74/300], Step [400/600], d_loss: 0.3128, g_loss: 0.5160, D(x): 0.78, D(G(z)): 0.36
# Epoch [74/300], Step [600/600], d_loss: 0.3159, g_loss: 0.5829, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.4270, g_loss: 0.4391, D(x): 0.66, D(G(z)): 0.39
# Epoch [75/300], Step [400/600], d_loss: 0.2392, g_loss: 0.7209, D(x): 0.78, D(G(z)): 0.27
# Epoch [75/300], Step [600/600], d_loss: 0.2335, g_loss: 0.5651, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.1592, g_loss: 0.6738, D(x): 0.80, D(G(z)): 0.18
# Epoch [76/300], Step [400/600], d_loss: 0.2913, g_loss: 0.6567, D(x): 0.65, D(G(z)): 0.23
# Epoch [76/300], Step [600/600], d_loss: 0.3427, g_loss: 0.4669, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.3816, g_loss: 0.6714, D(x): 0.61, D(G(z)): 0.24
# Epoch [77/300], Step [400/600], d_loss: 0.4880, g_loss: 0.5901, D(x): 0.61, D(G(z)): 0.40
# Epoch [77/300], Step [600/600], d_loss: 0.4683, g_loss: 0.6607, D(x): 0.56, D(G(z)): 0.29
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.3986, g_loss: 0.6276, D(x): 0.64, D(G(z)): 0.33
# Epoch [78/300], Step [400/600], d_loss: 0.2937, g_loss: 0.5939, D(x): 0.70, D(G(z)): 0.30
# Epoch [78/300], Step [600/600], d_loss: 0.3150, g_loss: 0.5623, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.2979, g_loss: 0.5376, D(x): 0.79, D(G(z)): 0.32
# Epoch [79/300], Step [400/600], d_loss: 0.2768, g_loss: 0.5630, D(x): 0.73, D(G(z)): 0.29
# Epoch [79/300], Step [600/600], d_loss: 0.4115, g_loss: 0.5467, D(x): 0.63, D(G(z)): 0.34
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.3577, g_loss: 0.6765, D(x): 0.61, D(G(z)): 0.27
# Epoch [80/300], Step [400/600], d_loss: 0.3753, g_loss: 0.5103, D(x): 0.75, D(G(z)): 0.43
# Epoch [80/300], Step [600/600], d_loss: 0.3269, g_loss: 0.5869, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.2993, g_loss: 0.5899, D(x): 0.66, D(G(z)): 0.25
# Epoch [81/300], Step [400/600], d_loss: 0.4347, g_loss: 0.5387, D(x): 0.65, D(G(z)): 0.42
# Epoch [81/300], Step [600/600], d_loss: 0.3309, g_loss: 0.5580, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.4043, g_loss: 0.6025, D(x): 0.55, D(G(z)): 0.23
# Epoch [82/300], Step [400/600], d_loss: 0.3365, g_loss: 0.6665, D(x): 0.62, D(G(z)): 0.23
# Epoch [82/300], Step [600/600], d_loss: 0.3765, g_loss: 0.5766, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.3950, g_loss: 0.5958, D(x): 0.73, D(G(z)): 0.42
# Epoch [83/300], Step [400/600], d_loss: 0.3065, g_loss: 0.5700, D(x): 0.66, D(G(z)): 0.25
# Epoch [83/300], Step [600/600], d_loss: 0.4616, g_loss: 0.3764, D(x): 0.63, D(G(z)): 0.44
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.3224, g_loss: 0.5950, D(x): 0.63, D(G(z)): 0.27
# Epoch [84/300], Step [400/600], d_loss: 0.3402, g_loss: 0.5258, D(x): 0.70, D(G(z)): 0.33
# Epoch [84/300], Step [600/600], d_loss: 0.4671, g_loss: 0.4873, D(x): 0.66, D(G(z)): 0.46
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.3075, g_loss: 0.5193, D(x): 0.72, D(G(z)): 0.32
# Epoch [85/300], Step [400/600], d_loss: 0.3480, g_loss: 0.4764, D(x): 0.68, D(G(z)): 0.34
# Epoch [85/300], Step [600/600], d_loss: 0.3297, g_loss: 0.5697, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.2948, g_loss: 0.6597, D(x): 0.67, D(G(z)): 0.23
# Epoch [86/300], Step [400/600], d_loss: 0.3209, g_loss: 0.5689, D(x): 0.71, D(G(z)): 0.33
# Epoch [86/300], Step [600/600], d_loss: 0.2117, g_loss: 0.7126, D(x): 0.73, D(G(z)): 0.20
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.3840, g_loss: 0.5860, D(x): 0.61, D(G(z)): 0.30
# Epoch [87/300], Step [400/600], d_loss: 0.4694, g_loss: 0.4760, D(x): 0.55, D(G(z)): 0.35
# Epoch [87/300], Step [600/600], d_loss: 0.2714, g_loss: 0.5241, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.2053, g_loss: 0.5893, D(x): 0.75, D(G(z)): 0.22
# Epoch [88/300], Step [400/600], d_loss: 0.4153, g_loss: 0.7039, D(x): 0.53, D(G(z)): 0.26
# Epoch [88/300], Step [600/600], d_loss: 0.3334, g_loss: 0.6651, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.4044, g_loss: 0.5448, D(x): 0.66, D(G(z)): 0.34
# Epoch [89/300], Step [400/600], d_loss: 0.2791, g_loss: 0.5910, D(x): 0.69, D(G(z)): 0.26
# Epoch [89/300], Step [600/600], d_loss: 0.2824, g_loss: 0.5865, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.2375, g_loss: 0.6894, D(x): 0.69, D(G(z)): 0.22
# Epoch [90/300], Step [400/600], d_loss: 0.4471, g_loss: 0.4653, D(x): 0.55, D(G(z)): 0.32
# Epoch [90/300], Step [600/600], d_loss: 0.3244, g_loss: 0.5915, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.3153, g_loss: 0.5408, D(x): 0.71, D(G(z)): 0.34
# Epoch [91/300], Step [400/600], d_loss: 0.2966, g_loss: 0.5534, D(x): 0.68, D(G(z)): 0.28
# Epoch [91/300], Step [600/600], d_loss: 0.3928, g_loss: 0.5273, D(x): 0.65, D(G(z)): 0.39
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.3082, g_loss: 0.6787, D(x): 0.66, D(G(z)): 0.24
# Epoch [92/300], Step [400/600], d_loss: 0.3132, g_loss: 0.5805, D(x): 0.70, D(G(z)): 0.32
# Epoch [92/300], Step [600/600], d_loss: 0.4728, g_loss: 0.3947, D(x): 0.60, D(G(z)): 0.45
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.3768, g_loss: 0.4534, D(x): 0.61, D(G(z)): 0.34
# Epoch [93/300], Step [400/600], d_loss: 0.4069, g_loss: 0.5118, D(x): 0.61, D(G(z)): 0.36
# Epoch [93/300], Step [600/600], d_loss: 0.3463, g_loss: 0.6130, D(x): 0.62, D(G(z)): 0.27
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.4286, g_loss: 0.4880, D(x): 0.63, D(G(z)): 0.41
# Epoch [94/300], Step [400/600], d_loss: 0.2576, g_loss: 0.5911, D(x): 0.70, D(G(z)): 0.27
# Epoch [94/300], Step [600/600], d_loss: 0.4668, g_loss: 0.5941, D(x): 0.55, D(G(z)): 0.35
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.2521, g_loss: 0.5919, D(x): 0.74, D(G(z)): 0.29
# Epoch [95/300], Step [400/600], d_loss: 0.2224, g_loss: 0.5316, D(x): 0.78, D(G(z)): 0.28
# Epoch [95/300], Step [600/600], d_loss: 0.4377, g_loss: 0.5038, D(x): 0.58, D(G(z)): 0.33
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.2952, g_loss: 0.5382, D(x): 0.72, D(G(z)): 0.31
# Epoch [96/300], Step [400/600], d_loss: 0.3479, g_loss: 0.5175, D(x): 0.70, D(G(z)): 0.36
# Epoch [96/300], Step [600/600], d_loss: 0.4044, g_loss: 0.5999, D(x): 0.65, D(G(z)): 0.37
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.2796, g_loss: 0.5942, D(x): 0.67, D(G(z)): 0.29
# Epoch [97/300], Step [400/600], d_loss: 0.2402, g_loss: 0.5857, D(x): 0.71, D(G(z)): 0.22
# Epoch [97/300], Step [600/600], d_loss: 0.4822, g_loss: 0.6947, D(x): 0.47, D(G(z)): 0.22
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.3146, g_loss: 0.5381, D(x): 0.69, D(G(z)): 0.33
# Epoch [98/300], Step [400/600], d_loss: 0.3320, g_loss: 0.5177, D(x): 0.69, D(G(z)): 0.34
# Epoch [98/300], Step [600/600], d_loss: 0.2284, g_loss: 0.6916, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.3689, g_loss: 0.4559, D(x): 0.72, D(G(z)): 0.43
# Epoch [99/300], Step [400/600], d_loss: 0.2884, g_loss: 0.6283, D(x): 0.66, D(G(z)): 0.26
# Epoch [99/300], Step [600/600], d_loss: 0.3732, g_loss: 0.5780, D(x): 0.59, D(G(z)): 0.29
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.3582, g_loss: 0.5442, D(x): 0.64, D(G(z)): 0.34
# Epoch [100/300], Step [400/600], d_loss: 0.2621, g_loss: 0.5993, D(x): 0.71, D(G(z)): 0.27
# Epoch [100/300], Step [600/600], d_loss: 0.4459, g_loss: 0.4406, D(x): 0.60, D(G(z)): 0.41
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.2273, g_loss: 0.5740, D(x): 0.77, D(G(z)): 0.28
# Epoch [101/300], Step [400/600], d_loss: 0.3615, g_loss: 0.5312, D(x): 0.65, D(G(z)): 0.33
# Epoch [101/300], Step [600/600], d_loss: 0.2960, g_loss: 0.6065, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.3321, g_loss: 0.5342, D(x): 0.72, D(G(z)): 0.34
# Epoch [102/300], Step [400/600], d_loss: 0.3460, g_loss: 0.6000, D(x): 0.64, D(G(z)): 0.30
# Epoch [102/300], Step [600/600], d_loss: 0.3182, g_loss: 0.5107, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.5789, g_loss: 0.5278, D(x): 0.57, D(G(z)): 0.46
# Epoch [103/300], Step [400/600], d_loss: 0.4256, g_loss: 0.4925, D(x): 0.70, D(G(z)): 0.46
# Epoch [103/300], Step [600/600], d_loss: 0.3445, g_loss: 0.5048, D(x): 0.64, D(G(z)): 0.32
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.3175, g_loss: 0.5808, D(x): 0.70, D(G(z)): 0.31
# Epoch [104/300], Step [400/600], d_loss: 0.2870, g_loss: 0.5154, D(x): 0.68, D(G(z)): 0.29
# Epoch [104/300], Step [600/600], d_loss: 0.3749, g_loss: 0.5411, D(x): 0.57, D(G(z)): 0.29
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.5103, g_loss: 0.4665, D(x): 0.53, D(G(z)): 0.39
# Epoch [105/300], Step [400/600], d_loss: 0.3727, g_loss: 0.4736, D(x): 0.72, D(G(z)): 0.41
# Epoch [105/300], Step [600/600], d_loss: 0.3458, g_loss: 0.5924, D(x): 0.63, D(G(z)): 0.28
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.3651, g_loss: 0.4273, D(x): 0.65, D(G(z)): 0.36
# Epoch [106/300], Step [400/600], d_loss: 0.2953, g_loss: 0.5557, D(x): 0.72, D(G(z)): 0.33
# Epoch [106/300], Step [600/600], d_loss: 0.3381, g_loss: 0.5268, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.4110, g_loss: 0.4484, D(x): 0.68, D(G(z)): 0.42
# Epoch [107/300], Step [400/600], d_loss: 0.3819, g_loss: 0.5344, D(x): 0.62, D(G(z)): 0.36
# Epoch [107/300], Step [600/600], d_loss: 0.3645, g_loss: 0.4731, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.4982, g_loss: 0.5098, D(x): 0.62, D(G(z)): 0.41
# Epoch [108/300], Step [400/600], d_loss: 0.4236, g_loss: 0.5217, D(x): 0.61, D(G(z)): 0.35
# Epoch [108/300], Step [600/600], d_loss: 0.1760, g_loss: 0.7709, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.2699, g_loss: 0.5530, D(x): 0.74, D(G(z)): 0.30
# Epoch [109/300], Step [400/600], d_loss: 0.3752, g_loss: 0.4154, D(x): 0.70, D(G(z)): 0.40
# Epoch [109/300], Step [600/600], d_loss: 0.3204, g_loss: 0.6522, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.3136, g_loss: 0.5108, D(x): 0.70, D(G(z)): 0.29
# Epoch [110/300], Step [400/600], d_loss: 0.2479, g_loss: 0.6902, D(x): 0.76, D(G(z)): 0.30
# Epoch [110/300], Step [600/600], d_loss: 0.4712, g_loss: 0.4061, D(x): 0.56, D(G(z)): 0.38
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.2424, g_loss: 0.6396, D(x): 0.73, D(G(z)): 0.22
# Epoch [111/300], Step [400/600], d_loss: 0.3721, g_loss: 0.4832, D(x): 0.72, D(G(z)): 0.43
# Epoch [111/300], Step [600/600], d_loss: 0.2886, g_loss: 0.5685, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.3155, g_loss: 0.5486, D(x): 0.72, D(G(z)): 0.33
# Epoch [112/300], Step [400/600], d_loss: 0.2290, g_loss: 0.5474, D(x): 0.72, D(G(z)): 0.24
# Epoch [112/300], Step [600/600], d_loss: 0.2660, g_loss: 0.5609, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.3607, g_loss: 0.5094, D(x): 0.61, D(G(z)): 0.33
# Epoch [113/300], Step [400/600], d_loss: 0.3824, g_loss: 0.5039, D(x): 0.66, D(G(z)): 0.38
# Epoch [113/300], Step [600/600], d_loss: 0.2910, g_loss: 0.6425, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.3453, g_loss: 0.4660, D(x): 0.66, D(G(z)): 0.34
# Epoch [114/300], Step [400/600], d_loss: 0.4295, g_loss: 0.4253, D(x): 0.65, D(G(z)): 0.43
# Epoch [114/300], Step [600/600], d_loss: 0.3901, g_loss: 0.6264, D(x): 0.59, D(G(z)): 0.27
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.3195, g_loss: 0.6985, D(x): 0.65, D(G(z)): 0.26
# Epoch [115/300], Step [400/600], d_loss: 0.4240, g_loss: 0.4922, D(x): 0.67, D(G(z)): 0.42
# Epoch [115/300], Step [600/600], d_loss: 0.4279, g_loss: 0.4306, D(x): 0.70, D(G(z)): 0.44
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.3744, g_loss: 0.5273, D(x): 0.70, D(G(z)): 0.38
# Epoch [116/300], Step [400/600], d_loss: 0.2280, g_loss: 0.5438, D(x): 0.73, D(G(z)): 0.24
# Epoch [116/300], Step [600/600], d_loss: 0.4417, g_loss: 0.5904, D(x): 0.57, D(G(z)): 0.31
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.4721, g_loss: 0.4180, D(x): 0.62, D(G(z)): 0.43
# Epoch [117/300], Step [400/600], d_loss: 0.3005, g_loss: 0.6158, D(x): 0.65, D(G(z)): 0.24
# Epoch [117/300], Step [600/600], d_loss: 0.2589, g_loss: 0.6630, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.3356, g_loss: 0.5017, D(x): 0.71, D(G(z)): 0.36
# Epoch [118/300], Step [400/600], d_loss: 0.3845, g_loss: 0.4319, D(x): 0.66, D(G(z)): 0.37
# Epoch [118/300], Step [600/600], d_loss: 0.3468, g_loss: 0.5748, D(x): 0.57, D(G(z)): 0.23
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.3049, g_loss: 0.6297, D(x): 0.70, D(G(z)): 0.30
# Epoch [119/300], Step [400/600], d_loss: 0.3429, g_loss: 0.5453, D(x): 0.71, D(G(z)): 0.36
# Epoch [119/300], Step [600/600], d_loss: 0.3351, g_loss: 0.5660, D(x): 0.60, D(G(z)): 0.29
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.4078, g_loss: 0.5580, D(x): 0.60, D(G(z)): 0.31
# Epoch [120/300], Step [400/600], d_loss: 0.3190, g_loss: 0.4730, D(x): 0.64, D(G(z)): 0.28
# Epoch [120/300], Step [600/600], d_loss: 0.3093, g_loss: 0.4603, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.4225, g_loss: 0.4671, D(x): 0.57, D(G(z)): 0.33
# Epoch [121/300], Step [400/600], d_loss: 0.5154, g_loss: 0.5853, D(x): 0.50, D(G(z)): 0.34
# Epoch [121/300], Step [600/600], d_loss: 0.3391, g_loss: 0.5390, D(x): 0.57, D(G(z)): 0.24
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.3739, g_loss: 0.5831, D(x): 0.60, D(G(z)): 0.29
# Epoch [122/300], Step [400/600], d_loss: 0.4174, g_loss: 0.3939, D(x): 0.69, D(G(z)): 0.44
# Epoch [122/300], Step [600/600], d_loss: 0.3458, g_loss: 0.4456, D(x): 0.70, D(G(z)): 0.38
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.3580, g_loss: 0.4841, D(x): 0.67, D(G(z)): 0.40
# Epoch [123/300], Step [400/600], d_loss: 0.2948, g_loss: 0.5621, D(x): 0.69, D(G(z)): 0.32
# Epoch [123/300], Step [600/600], d_loss: 0.3119, g_loss: 0.5811, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.2566, g_loss: 0.6055, D(x): 0.70, D(G(z)): 0.27
# Epoch [124/300], Step [400/600], d_loss: 0.2885, g_loss: 0.5158, D(x): 0.74, D(G(z)): 0.35
# Epoch [124/300], Step [600/600], d_loss: 0.3823, g_loss: 0.4581, D(x): 0.74, D(G(z)): 0.44
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.2209, g_loss: 0.6419, D(x): 0.76, D(G(z)): 0.26
# Epoch [125/300], Step [400/600], d_loss: 0.3968, g_loss: 0.5945, D(x): 0.64, D(G(z)): 0.36
# Epoch [125/300], Step [600/600], d_loss: 0.3090, g_loss: 0.6107, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.4049, g_loss: 0.5208, D(x): 0.63, D(G(z)): 0.38
# Epoch [126/300], Step [400/600], d_loss: 0.3284, g_loss: 0.5270, D(x): 0.72, D(G(z)): 0.37
# Epoch [126/300], Step [600/600], d_loss: 0.3335, g_loss: 0.4633, D(x): 0.74, D(G(z)): 0.40
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.2221, g_loss: 0.6604, D(x): 0.70, D(G(z)): 0.19
# Epoch [127/300], Step [400/600], d_loss: 0.4625, g_loss: 0.4952, D(x): 0.62, D(G(z)): 0.42
# Epoch [127/300], Step [600/600], d_loss: 0.3412, g_loss: 0.4164, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.3876, g_loss: 0.5690, D(x): 0.59, D(G(z)): 0.31
# Epoch [128/300], Step [400/600], d_loss: 0.4288, g_loss: 0.5672, D(x): 0.58, D(G(z)): 0.34
# Epoch [128/300], Step [600/600], d_loss: 0.3078, g_loss: 0.5993, D(x): 0.62, D(G(z)): 0.25
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.4398, g_loss: 0.5317, D(x): 0.58, D(G(z)): 0.40
# Epoch [129/300], Step [400/600], d_loss: 0.4433, g_loss: 0.5281, D(x): 0.59, D(G(z)): 0.37
# Epoch [129/300], Step [600/600], d_loss: 0.3045, g_loss: 0.6222, D(x): 0.64, D(G(z)): 0.25
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.4613, g_loss: 0.5181, D(x): 0.56, D(G(z)): 0.37
# Epoch [130/300], Step [400/600], d_loss: 0.4942, g_loss: 0.4624, D(x): 0.57, D(G(z)): 0.40
# Epoch [130/300], Step [600/600], d_loss: 0.4932, g_loss: 0.4108, D(x): 0.60, D(G(z)): 0.43
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.3626, g_loss: 0.6145, D(x): 0.67, D(G(z)): 0.35
# Epoch [131/300], Step [400/600], d_loss: 0.3004, g_loss: 0.6346, D(x): 0.71, D(G(z)): 0.31
# Epoch [131/300], Step [600/600], d_loss: 0.3171, g_loss: 0.5288, D(x): 0.65, D(G(z)): 0.31
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.3265, g_loss: 0.5423, D(x): 0.65, D(G(z)): 0.30
# Epoch [132/300], Step [400/600], d_loss: 0.4301, g_loss: 0.5885, D(x): 0.58, D(G(z)): 0.32
# Epoch [132/300], Step [600/600], d_loss: 0.3700, g_loss: 0.6320, D(x): 0.58, D(G(z)): 0.27
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.3455, g_loss: 0.5190, D(x): 0.71, D(G(z)): 0.37
# Epoch [133/300], Step [400/600], d_loss: 0.3785, g_loss: 0.4776, D(x): 0.68, D(G(z)): 0.41
# Epoch [133/300], Step [600/600], d_loss: 0.3402, g_loss: 0.5120, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.4269, g_loss: 0.4143, D(x): 0.63, D(G(z)): 0.42
# Epoch [134/300], Step [400/600], d_loss: 0.3467, g_loss: 0.6102, D(x): 0.66, D(G(z)): 0.32
# Epoch [134/300], Step [600/600], d_loss: 0.3469, g_loss: 0.6112, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.4016, g_loss: 0.4245, D(x): 0.59, D(G(z)): 0.33
# Epoch [135/300], Step [400/600], d_loss: 0.4354, g_loss: 0.4566, D(x): 0.62, D(G(z)): 0.39
# Epoch [135/300], Step [600/600], d_loss: 0.2236, g_loss: 0.5384, D(x): 0.76, D(G(z)): 0.26
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.3008, g_loss: 0.5247, D(x): 0.68, D(G(z)): 0.33
# Epoch [136/300], Step [400/600], d_loss: 0.2486, g_loss: 0.5926, D(x): 0.69, D(G(z)): 0.25
# Epoch [136/300], Step [600/600], d_loss: 0.3870, g_loss: 0.5063, D(x): 0.60, D(G(z)): 0.32
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.3877, g_loss: 0.5103, D(x): 0.57, D(G(z)): 0.30
# Epoch [137/300], Step [400/600], d_loss: 0.3942, g_loss: 0.5127, D(x): 0.60, D(G(z)): 0.32
# Epoch [137/300], Step [600/600], d_loss: 0.4028, g_loss: 0.4499, D(x): 0.64, D(G(z)): 0.38
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.4251, g_loss: 0.4470, D(x): 0.64, D(G(z)): 0.42
# Epoch [138/300], Step [400/600], d_loss: 0.2850, g_loss: 0.5413, D(x): 0.63, D(G(z)): 0.23
# Epoch [138/300], Step [600/600], d_loss: 0.3505, g_loss: 0.4661, D(x): 0.65, D(G(z)): 0.35
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.3481, g_loss: 0.4732, D(x): 0.63, D(G(z)): 0.32
# Epoch [139/300], Step [400/600], d_loss: 0.3788, g_loss: 0.5749, D(x): 0.64, D(G(z)): 0.37
# Epoch [139/300], Step [600/600], d_loss: 0.3276, g_loss: 0.5957, D(x): 0.62, D(G(z)): 0.28
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.3469, g_loss: 0.4806, D(x): 0.69, D(G(z)): 0.38
# Epoch [140/300], Step [400/600], d_loss: 0.3548, g_loss: 0.4319, D(x): 0.69, D(G(z)): 0.38
# Epoch [140/300], Step [600/600], d_loss: 0.3779, g_loss: 0.4945, D(x): 0.65, D(G(z)): 0.36
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.3724, g_loss: 0.4358, D(x): 0.60, D(G(z)): 0.33
# Epoch [141/300], Step [400/600], d_loss: 0.4589, g_loss: 0.4436, D(x): 0.71, D(G(z)): 0.51
# Epoch [141/300], Step [600/600], d_loss: 0.3555, g_loss: 0.4604, D(x): 0.63, D(G(z)): 0.32
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.2121, g_loss: 0.5882, D(x): 0.74, D(G(z)): 0.26
# Epoch [142/300], Step [400/600], d_loss: 0.3450, g_loss: 0.5520, D(x): 0.68, D(G(z)): 0.34
# Epoch [142/300], Step [600/600], d_loss: 0.4297, g_loss: 0.4698, D(x): 0.65, D(G(z)): 0.42
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.3560, g_loss: 0.5026, D(x): 0.66, D(G(z)): 0.35
# Epoch [143/300], Step [400/600], d_loss: 0.3231, g_loss: 0.5533, D(x): 0.68, D(G(z)): 0.33
# Epoch [143/300], Step [600/600], d_loss: 0.3060, g_loss: 0.6187, D(x): 0.65, D(G(z)): 0.28
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.4321, g_loss: 0.5538, D(x): 0.53, D(G(z)): 0.27
# Epoch [144/300], Step [400/600], d_loss: 0.3244, g_loss: 0.4769, D(x): 0.69, D(G(z)): 0.36
# Epoch [144/300], Step [600/600], d_loss: 0.3684, g_loss: 0.4834, D(x): 0.68, D(G(z)): 0.37
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.5015, g_loss: 0.4060, D(x): 0.57, D(G(z)): 0.41
# Epoch [145/300], Step [400/600], d_loss: 0.3134, g_loss: 0.6440, D(x): 0.66, D(G(z)): 0.29
# Epoch [145/300], Step [600/600], d_loss: 0.5213, g_loss: 0.4071, D(x): 0.63, D(G(z)): 0.50
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.3792, g_loss: 0.4974, D(x): 0.64, D(G(z)): 0.37
# Epoch [146/300], Step [400/600], d_loss: 0.3982, g_loss: 0.4103, D(x): 0.65, D(G(z)): 0.39
# Epoch [146/300], Step [600/600], d_loss: 0.2760, g_loss: 0.6209, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.3963, g_loss: 0.4473, D(x): 0.64, D(G(z)): 0.40
# Epoch [147/300], Step [400/600], d_loss: 0.4394, g_loss: 0.4334, D(x): 0.60, D(G(z)): 0.41
# Epoch [147/300], Step [600/600], d_loss: 0.2890, g_loss: 0.5786, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.2627, g_loss: 0.5869, D(x): 0.66, D(G(z)): 0.25
# Epoch [148/300], Step [400/600], d_loss: 0.5818, g_loss: 0.3763, D(x): 0.49, D(G(z)): 0.41
# Epoch [148/300], Step [600/600], d_loss: 0.3875, g_loss: 0.4454, D(x): 0.68, D(G(z)): 0.39
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.4582, g_loss: 0.4037, D(x): 0.56, D(G(z)): 0.37
# Epoch [149/300], Step [400/600], d_loss: 0.4628, g_loss: 0.5075, D(x): 0.56, D(G(z)): 0.39
# Epoch [149/300], Step [600/600], d_loss: 0.2753, g_loss: 0.5959, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 0.3651, g_loss: 0.4643, D(x): 0.67, D(G(z)): 0.37
# Epoch [150/300], Step [400/600], d_loss: 0.5171, g_loss: 0.4312, D(x): 0.55, D(G(z)): 0.43
# Epoch [150/300], Step [600/600], d_loss: 0.4711, g_loss: 0.4476, D(x): 0.55, D(G(z)): 0.36
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.4576, g_loss: 0.3894, D(x): 0.64, D(G(z)): 0.43
# Epoch [151/300], Step [400/600], d_loss: 0.4113, g_loss: 0.5198, D(x): 0.61, D(G(z)): 0.36
# Epoch [151/300], Step [600/600], d_loss: 0.4444, g_loss: 0.4389, D(x): 0.59, D(G(z)): 0.41
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.4871, g_loss: 0.4175, D(x): 0.53, D(G(z)): 0.36
# Epoch [152/300], Step [400/600], d_loss: 0.3827, g_loss: 0.4314, D(x): 0.60, D(G(z)): 0.32
# Epoch [152/300], Step [600/600], d_loss: 0.3620, g_loss: 0.4360, D(x): 0.68, D(G(z)): 0.39
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.3205, g_loss: 0.4743, D(x): 0.70, D(G(z)): 0.37
# Epoch [153/300], Step [400/600], d_loss: 0.3208, g_loss: 0.4845, D(x): 0.72, D(G(z)): 0.38
# Epoch [153/300], Step [600/600], d_loss: 0.4575, g_loss: 0.4618, D(x): 0.59, D(G(z)): 0.41
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.3912, g_loss: 0.3593, D(x): 0.63, D(G(z)): 0.38
# Epoch [154/300], Step [400/600], d_loss: 0.3239, g_loss: 0.4653, D(x): 0.71, D(G(z)): 0.39
# Epoch [154/300], Step [600/600], d_loss: 0.4045, g_loss: 0.4795, D(x): 0.66, D(G(z)): 0.41
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.3850, g_loss: 0.5089, D(x): 0.64, D(G(z)): 0.36
# Epoch [155/300], Step [400/600], d_loss: 0.4701, g_loss: 0.4657, D(x): 0.52, D(G(z)): 0.33
# Epoch [155/300], Step [600/600], d_loss: 0.2976, g_loss: 0.5330, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.4009, g_loss: 0.4478, D(x): 0.61, D(G(z)): 0.37
# Epoch [156/300], Step [400/600], d_loss: 0.3096, g_loss: 0.5491, D(x): 0.63, D(G(z)): 0.30
# Epoch [156/300], Step [600/600], d_loss: 0.2556, g_loss: 0.5678, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.4138, g_loss: 0.4390, D(x): 0.64, D(G(z)): 0.41
# Epoch [157/300], Step [400/600], d_loss: 0.3302, g_loss: 0.5846, D(x): 0.69, D(G(z)): 0.36
# Epoch [157/300], Step [600/600], d_loss: 0.4103, g_loss: 0.4104, D(x): 0.62, D(G(z)): 0.40
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 0.3017, g_loss: 0.5500, D(x): 0.70, D(G(z)): 0.34
# Epoch [158/300], Step [400/600], d_loss: 0.3704, g_loss: 0.5111, D(x): 0.59, D(G(z)): 0.32
# Epoch [158/300], Step [600/600], d_loss: 0.4067, g_loss: 0.4651, D(x): 0.64, D(G(z)): 0.39
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.3500, g_loss: 0.4824, D(x): 0.63, D(G(z)): 0.32
# Epoch [159/300], Step [400/600], d_loss: 0.3553, g_loss: 0.5775, D(x): 0.62, D(G(z)): 0.30
# Epoch [159/300], Step [600/600], d_loss: 0.3488, g_loss: 0.5371, D(x): 0.64, D(G(z)): 0.33
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.1974, g_loss: 0.6305, D(x): 0.74, D(G(z)): 0.22
# ...
# Epoch [247/300], Step [400/600], d_loss: 0.3655, g_loss: 0.4850, D(x): 0.62, D(G(z)): 0.35
# Epoch [247/300], Step [600/600], d_loss: 0.5609, g_loss: 0.3110, D(x): 0.54, D(G(z)): 0.49
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.3242, g_loss: 0.5194, D(x): 0.64, D(G(z)): 0.33
# Epoch [248/300], Step [400/600], d_loss: 0.2102, g_loss: 0.5469, D(x): 0.73, D(G(z)): 0.25
# Epoch [248/300], Step [600/600], d_loss: 0.4125, g_loss: 0.4141, D(x): 0.67, D(G(z)): 0.44
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.4721, g_loss: 0.3692, D(x): 0.57, D(G(z)): 0.43
# Epoch [249/300], Step [400/600], d_loss: 0.5671, g_loss: 0.3368, D(x): 0.51, D(G(z)): 0.48
# Epoch [249/300], Step [600/600], d_loss: 0.2713, g_loss: 0.5007, D(x): 0.66, D(G(z)): 0.31
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.3835, g_loss: 0.4613, D(x): 0.62, D(G(z)): 0.37
# Epoch [250/300], Step [400/600], d_loss: 0.2290, g_loss: 0.5782, D(x): 0.70, D(G(z)): 0.25
# Epoch [250/300], Step [600/600], d_loss: 0.4124, g_loss: 0.4402, D(x): 0.59, D(G(z)): 0.39
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.6192, g_loss: 0.2900, D(x): 0.56, D(G(z)): 0.56
# Epoch [251/300], Step [400/600], d_loss: 0.3155, g_loss: 0.4915, D(x): 0.64, D(G(z)): 0.33
# Epoch [251/300], Step [600/600], d_loss: 0.3355, g_loss: 0.5077, D(x): 0.60, D(G(z)): 0.28
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.3647, g_loss: 0.4669, D(x): 0.60, D(G(z)): 0.33
# Epoch [252/300], Step [400/600], d_loss: 0.2293, g_loss: 0.6144, D(x): 0.71, D(G(z)): 0.28
# Epoch [252/300], Step [600/600], d_loss: 0.2459, g_loss: 0.5350, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.4069, g_loss: 0.3660, D(x): 0.63, D(G(z)): 0.42
# Epoch [253/300], Step [400/600], d_loss: 0.4346, g_loss: 0.4917, D(x): 0.56, D(G(z)): 0.38
# Epoch [253/300], Step [600/600], d_loss: 0.2274, g_loss: 0.6285, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.3916, g_loss: 0.4318, D(x): 0.70, D(G(z)): 0.44
# Epoch [254/300], Step [400/600], d_loss: 0.4385, g_loss: 0.5069, D(x): 0.54, D(G(z)): 0.38
# Epoch [254/300], Step [600/600], d_loss: 0.4291, g_loss: 0.4289, D(x): 0.58, D(G(z)): 0.39
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.4109, g_loss: 0.4066, D(x): 0.59, D(G(z)): 0.38
# Epoch [255/300], Step [400/600], d_loss: 0.2409, g_loss: 0.6146, D(x): 0.69, D(G(z)): 0.27
# Epoch [255/300], Step [600/600], d_loss: 0.6112, g_loss: 0.3810, D(x): 0.49, D(G(z)): 0.48
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.4059, g_loss: 0.3809, D(x): 0.62, D(G(z)): 0.41
# Epoch [256/300], Step [400/600], d_loss: 0.2569, g_loss: 0.5399, D(x): 0.67, D(G(z)): 0.26
# Epoch [256/300], Step [600/600], d_loss: 0.5388, g_loss: 0.3788, D(x): 0.51, D(G(z)): 0.45
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.5225, g_loss: 0.4006, D(x): 0.51, D(G(z)): 0.44
# Epoch [257/300], Step [400/600], d_loss: 0.4105, g_loss: 0.4755, D(x): 0.62, D(G(z)): 0.42
# Epoch [257/300], Step [600/600], d_loss: 0.3214, g_loss: 0.4753, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.4646, g_loss: 0.4299, D(x): 0.61, D(G(z)): 0.45
# Epoch [258/300], Step [400/600], d_loss: 0.2566, g_loss: 0.5818, D(x): 0.67, D(G(z)): 0.27
# Epoch [258/300], Step [600/600], d_loss: 0.2107, g_loss: 0.5647, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.4819, g_loss: 0.3119, D(x): 0.60, D(G(z)): 0.48
# Epoch [259/300], Step [400/600], d_loss: 0.3740, g_loss: 0.4643, D(x): 0.61, D(G(z)): 0.37
# Epoch [259/300], Step [600/600], d_loss: 0.2693, g_loss: 0.5796, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.4100, g_loss: 0.4546, D(x): 0.61, D(G(z)): 0.41
# Epoch [260/300], Step [400/600], d_loss: 0.2685, g_loss: 0.5431, D(x): 0.73, D(G(z)): 0.35
# Epoch [260/300], Step [600/600], d_loss: 0.3272, g_loss: 0.4845, D(x): 0.70, D(G(z)): 0.38
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.4900, g_loss: 0.3711, D(x): 0.58, D(G(z)): 0.45
# Epoch [261/300], Step [400/600], d_loss: 0.3776, g_loss: 0.4608, D(x): 0.62, D(G(z)): 0.39
# Epoch [261/300], Step [600/600], d_loss: 0.3592, g_loss: 0.4724, D(x): 0.63, D(G(z)): 0.37
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.3528, g_loss: 0.4651, D(x): 0.64, D(G(z)): 0.35
# Epoch [262/300], Step [400/600], d_loss: 0.3424, g_loss: 0.4281, D(x): 0.69, D(G(z)): 0.41
# Epoch [262/300], Step [600/600], d_loss: 0.3906, g_loss: 0.4454, D(x): 0.63, D(G(z)): 0.40
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.5325, g_loss: 0.4032, D(x): 0.56, D(G(z)): 0.48
# Epoch [263/300], Step [400/600], d_loss: 0.2006, g_loss: 0.5952, D(x): 0.78, D(G(z)): 0.28
# Epoch [263/300], Step [600/600], d_loss: 0.4647, g_loss: 0.4782, D(x): 0.55, D(G(z)): 0.39
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.3272, g_loss: 0.4517, D(x): 0.67, D(G(z)): 0.35
# Epoch [264/300], Step [400/600], d_loss: 0.2510, g_loss: 0.5549, D(x): 0.69, D(G(z)): 0.27
# Epoch [264/300], Step [600/600], d_loss: 0.3320, g_loss: 0.4714, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.4312, g_loss: 0.4249, D(x): 0.65, D(G(z)): 0.45
# Epoch [265/300], Step [400/600], d_loss: 0.4197, g_loss: 0.3251, D(x): 0.68, D(G(z)): 0.47
# Epoch [265/300], Step [600/600], d_loss: 0.1916, g_loss: 0.5960, D(x): 0.73, D(G(z)): 0.23
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.2690, g_loss: 0.5242, D(x): 0.73, D(G(z)): 0.34
# Epoch [266/300], Step [400/600], d_loss: 0.5567, g_loss: 0.3354, D(x): 0.57, D(G(z)): 0.53
# Epoch [266/300], Step [600/600], d_loss: 0.2947, g_loss: 0.4822, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.3060, g_loss: 0.5039, D(x): 0.69, D(G(z)): 0.34
# Epoch [267/300], Step [400/600], d_loss: 0.5126, g_loss: 0.4357, D(x): 0.46, D(G(z)): 0.35
# Epoch [267/300], Step [600/600], d_loss: 0.5526, g_loss: 0.4220, D(x): 0.44, D(G(z)): 0.37
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.3406, g_loss: 0.5222, D(x): 0.61, D(G(z)): 0.34
# Epoch [268/300], Step [400/600], d_loss: 0.2558, g_loss: 0.4876, D(x): 0.67, D(G(z)): 0.29
# Epoch [268/300], Step [600/600], d_loss: 0.3774, g_loss: 0.3773, D(x): 0.61, D(G(z)): 0.38
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.5394, g_loss: 0.3386, D(x): 0.53, D(G(z)): 0.46
# Epoch [269/300], Step [400/600], d_loss: 0.3336, g_loss: 0.4646, D(x): 0.65, D(G(z)): 0.37
# Epoch [269/300], Step [600/600], d_loss: 0.3526, g_loss: 0.5005, D(x): 0.63, D(G(z)): 0.35
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.4499, g_loss: 0.4011, D(x): 0.57, D(G(z)): 0.43
# Epoch [270/300], Step [400/600], d_loss: 0.3202, g_loss: 0.3650, D(x): 0.69, D(G(z)): 0.38
# Epoch [270/300], Step [600/600], d_loss: 0.4922, g_loss: 0.3841, D(x): 0.52, D(G(z)): 0.39
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.3342, g_loss: 0.5390, D(x): 0.67, D(G(z)): 0.37
# Epoch [271/300], Step [400/600], d_loss: 0.3322, g_loss: 0.4762, D(x): 0.66, D(G(z)): 0.34
# Epoch [271/300], Step [600/600], d_loss: 0.4344, g_loss: 0.4334, D(x): 0.55, D(G(z)): 0.38
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.4021, g_loss: 0.4450, D(x): 0.58, D(G(z)): 0.38
# Epoch [272/300], Step [400/600], d_loss: 0.4721, g_loss: 0.4201, D(x): 0.57, D(G(z)): 0.43
# Epoch [272/300], Step [600/600], d_loss: 0.3592, g_loss: 0.5156, D(x): 0.63, D(G(z)): 0.37
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.2529, g_loss: 0.6300, D(x): 0.70, D(G(z)): 0.26
# Epoch [273/300], Step [400/600], d_loss: 0.3458, g_loss: 0.4841, D(x): 0.66, D(G(z)): 0.38
# Epoch [273/300], Step [600/600], d_loss: 0.3798, g_loss: 0.4375, D(x): 0.62, D(G(z)): 0.37
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.3664, g_loss: 0.5112, D(x): 0.62, D(G(z)): 0.36
# Epoch [274/300], Step [400/600], d_loss: 0.2987, g_loss: 0.5446, D(x): 0.62, D(G(z)): 0.29
# Epoch [274/300], Step [600/600], d_loss: 0.2715, g_loss: 0.5484, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.4343, g_loss: 0.4074, D(x): 0.54, D(G(z)): 0.38
# Epoch [275/300], Step [400/600], d_loss: 0.3742, g_loss: 0.4380, D(x): 0.66, D(G(z)): 0.41
# Epoch [275/300], Step [600/600], d_loss: 0.2674, g_loss: 0.5187, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.3700, g_loss: 0.4248, D(x): 0.62, D(G(z)): 0.38
# Epoch [276/300], Step [400/600], d_loss: 0.2414, g_loss: 0.4907, D(x): 0.72, D(G(z)): 0.31
# Epoch [276/300], Step [600/600], d_loss: 0.2637, g_loss: 0.5202, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.4113, g_loss: 0.4681, D(x): 0.57, D(G(z)): 0.37
# Epoch [277/300], Step [400/600], d_loss: 0.3191, g_loss: 0.5107, D(x): 0.63, D(G(z)): 0.30
# Epoch [277/300], Step [600/600], d_loss: 0.3835, g_loss: 0.4381, D(x): 0.62, D(G(z)): 0.38
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.3466, g_loss: 0.4284, D(x): 0.60, D(G(z)): 0.33
# Epoch [278/300], Step [400/600], d_loss: 0.3135, g_loss: 0.4694, D(x): 0.68, D(G(z)): 0.35
# Epoch [278/300], Step [600/600], d_loss: 0.2780, g_loss: 0.5509, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.5657, g_loss: 0.3709, D(x): 0.53, D(G(z)): 0.48
# Epoch [279/300], Step [400/600], d_loss: 0.4695, g_loss: 0.4045, D(x): 0.60, D(G(z)): 0.48
# Epoch [279/300], Step [600/600], d_loss: 0.3406, g_loss: 0.5061, D(x): 0.64, D(G(z)): 0.33
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.4318, g_loss: 0.4802, D(x): 0.51, D(G(z)): 0.32
# Epoch [280/300], Step [400/600], d_loss: 0.4111, g_loss: 0.4466, D(x): 0.61, D(G(z)): 0.40
# Epoch [280/300], Step [600/600], d_loss: 0.2577, g_loss: 0.5017, D(x): 0.70, D(G(z)): 0.31
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.5188, g_loss: 0.3836, D(x): 0.61, D(G(z)): 0.53
# Epoch [281/300], Step [400/600], d_loss: 0.4846, g_loss: 0.4490, D(x): 0.51, D(G(z)): 0.36
# Epoch [281/300], Step [600/600], d_loss: 0.3239, g_loss: 0.5198, D(x): 0.65, D(G(z)): 0.32
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.3393, g_loss: 0.4877, D(x): 0.60, D(G(z)): 0.31
# Epoch [282/300], Step [400/600], d_loss: 0.3040, g_loss: 0.5122, D(x): 0.66, D(G(z)): 0.33
# Epoch [282/300], Step [600/600], d_loss: 0.2941, g_loss: 0.4354, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.2590, g_loss: 0.5255, D(x): 0.63, D(G(z)): 0.22
# Epoch [283/300], Step [400/600], d_loss: 0.4604, g_loss: 0.3378, D(x): 0.61, D(G(z)): 0.44
# Epoch [283/300], Step [600/600], d_loss: 0.2732, g_loss: 0.4622, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.4317, g_loss: 0.3213, D(x): 0.55, D(G(z)): 0.37
# Epoch [284/300], Step [400/600], d_loss: 0.3903, g_loss: 0.4146, D(x): 0.70, D(G(z)): 0.46
# Epoch [284/300], Step [600/600], d_loss: 0.6349, g_loss: 0.3482, D(x): 0.47, D(G(z)): 0.50
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.4396, g_loss: 0.4237, D(x): 0.56, D(G(z)): 0.39
# Epoch [285/300], Step [400/600], d_loss: 0.5309, g_loss: 0.4684, D(x): 0.54, D(G(z)): 0.41
# Epoch [285/300], Step [600/600], d_loss: 0.3559, g_loss: 0.4038, D(x): 0.67, D(G(z)): 0.40
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.2285, g_loss: 0.5703, D(x): 0.69, D(G(z)): 0.23
# Epoch [286/300], Step [400/600], d_loss: 0.3187, g_loss: 0.4669, D(x): 0.66, D(G(z)): 0.35
# Epoch [286/300], Step [600/600], d_loss: 0.2736, g_loss: 0.5462, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.3113, g_loss: 0.4086, D(x): 0.69, D(G(z)): 0.38
# Epoch [287/300], Step [400/600], d_loss: 0.4462, g_loss: 0.4035, D(x): 0.62, D(G(z)): 0.45
# Epoch [287/300], Step [600/600], d_loss: 0.3235, g_loss: 0.4133, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.4975, g_loss: 0.4627, D(x): 0.51, D(G(z)): 0.39
# Epoch [288/300], Step [400/600], d_loss: 0.3585, g_loss: 0.5118, D(x): 0.62, D(G(z)): 0.31
# Epoch [288/300], Step [600/600], d_loss: 0.3521, g_loss: 0.4028, D(x): 0.63, D(G(z)): 0.36
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.4775, g_loss: 0.4061, D(x): 0.58, D(G(z)): 0.44
# Epoch [289/300], Step [400/600], d_loss: 0.4165, g_loss: 0.4740, D(x): 0.58, D(G(z)): 0.36
# Epoch [289/300], Step [600/600], d_loss: 0.5109, g_loss: 0.4419, D(x): 0.52, D(G(z)): 0.40
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.3465, g_loss: 0.5387, D(x): 0.62, D(G(z)): 0.33
# Epoch [290/300], Step [400/600], d_loss: 0.2521, g_loss: 0.5690, D(x): 0.65, D(G(z)): 0.24
# Epoch [290/300], Step [600/600], d_loss: 0.2601, g_loss: 0.4957, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.2031, g_loss: 0.5427, D(x): 0.73, D(G(z)): 0.25
# Epoch [291/300], Step [400/600], d_loss: 0.3929, g_loss: 0.4455, D(x): 0.64, D(G(z)): 0.41
# Epoch [291/300], Step [600/600], d_loss: 0.2741, g_loss: 0.5514, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.3816, g_loss: 0.4900, D(x): 0.61, D(G(z)): 0.38
# Epoch [292/300], Step [400/600], d_loss: 0.3883, g_loss: 0.4630, D(x): 0.65, D(G(z)): 0.40
# Epoch [292/300], Step [600/600], d_loss: 0.4227, g_loss: 0.4749, D(x): 0.58, D(G(z)): 0.37
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.2916, g_loss: 0.4970, D(x): 0.68, D(G(z)): 0.32
# Epoch [293/300], Step [400/600], d_loss: 0.2778, g_loss: 0.4957, D(x): 0.68, D(G(z)): 0.30
# Epoch [293/300], Step [600/600], d_loss: 0.2777, g_loss: 0.4876, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.2541, g_loss: 0.5330, D(x): 0.69, D(G(z)): 0.29
# Epoch [294/300], Step [400/600], d_loss: 0.2655, g_loss: 0.5256, D(x): 0.71, D(G(z)): 0.33
# Epoch [294/300], Step [600/600], d_loss: 0.2172, g_loss: 0.5581, D(x): 0.71, D(G(z)): 0.23
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.4924, g_loss: 0.3999, D(x): 0.55, D(G(z)): 0.43
# Epoch [295/300], Step [400/600], d_loss: 0.3072, g_loss: 0.5477, D(x): 0.70, D(G(z)): 0.35
# Epoch [295/300], Step [600/600], d_loss: 0.2913, g_loss: 0.6250, D(x): 0.62, D(G(z)): 0.23
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.3309, g_loss: 0.5174, D(x): 0.65, D(G(z)): 0.35
# Epoch [296/300], Step [400/600], d_loss: 0.4014, g_loss: 0.4412, D(x): 0.61, D(G(z)): 0.38
# Epoch [296/300], Step [600/600], d_loss: 0.4105, g_loss: 0.3770, D(x): 0.61, D(G(z)): 0.42
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.3500, g_loss: 0.4541, D(x): 0.61, D(G(z)): 0.34
# Epoch [297/300], Step [400/600], d_loss: 0.3156, g_loss: 0.4891, D(x): 0.69, D(G(z)): 0.36
# Epoch [297/300], Step [600/600], d_loss: 0.2981, g_loss: 0.5302, D(x): 0.69, D(G(z)): 0.33
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.2533, g_loss: 0.5541, D(x): 0.70, D(G(z)): 0.31
# Epoch [298/300], Step [400/600], d_loss: 0.2483, g_loss: 0.6049, D(x): 0.69, D(G(z)): 0.28
# Epoch [298/300], Step [600/600], d_loss: 0.2335, g_loss: 0.5702, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.2498, g_loss: 0.5729, D(x): 0.70, D(G(z)): 0.30
# Epoch [299/300], Step [400/600], d_loss: 0.2751, g_loss: 0.5126, D(x): 0.69, D(G(z)): 0.33
# Epoch [299/300], Step [600/600], d_loss: 0.3468, g_loss: 0.4364, D(x): 0.66, D(G(z)): 0.40
# Saving fake_images-0300.png
# CPU times: user 2h 20min 40s, sys: 46.8 s, total: 2h 21min 27s
# Wall time: 2h 22min 52s

# %% [markdown]
# Check some of the saved images created by the Generator

# %%
Image('./samples_chk_mse/fake_images-0001.png')

# %%
Image('./samples_chk_mse/fake_images-0099.png')

# %%
Image('./samples_chk_mse/fake_images-0200.png')

# %%
Image('./samples_chk_mse/fake_images-0300.png')

# %% [markdown]
# View the losses and accuracies

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# #### GAN models are hard to train. I am showing the images for the trained data at image 1, 99, 200 and 300. There were a total of 300 epochs for this step. As you can see from the "Loss" graph, around 250th epoch the images would start to look more similar. This is due to using the MSE loss function instead of the binary cross entropy loss function.

# %% [markdown]
# **Step4. Save the model weights in the folder to be used later.**

# %%
# Save checkpoint function saves the state dictionaries for model and optimizer
# Save the model checkpoints

# Define your checkpoint directory and prefix
checkpoint_dir = './training_checkpoints_mse'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

# Ensure the checkpoint directory exists
os.makedirs(checkpoint_dir, exist_ok=True)

# To save a checkpoint
def save_checkpoint(epoch, genG, discriM, g_optimizer, d_optimizer, filename="checkpoint.pth.tar"):
    save_path = os.path.join(checkpoint_dir, f"{filename}_{epoch}")
    torch.save({
        'Generator': G.state_dict(),
        'Discriminator': D.state_dict(),
        'G_optimizer_state_dict': g_optimizer.state_dict(),
        'D_optimizer_state_dict': d_optimizer.state_dict(),
    }, save_path)
    print(f"Checkpoint saved to {save_path}")

# %%
checkpoint = save_checkpoint(num_epochs, G, D, g_optimizer, d_optimizer)
# Out:
# Checkpoint saved to ./training_checkpoints_mse/checkpoint.pth.tar_300

# %% [markdown]
# **Step5. Load the model using the saved weights.**

# %%
# To load a checkpoint, loads the state dictionaries for model and optimizer

def load_checkpoint(model_path, genG, discriM, genG_optimizer, discriM_optimizer):
    checkpoint = torch.load(model_path)
    genG.load_state_dict(checkpoint['Generator'])
    discriM.load_state_dict(checkpoint['Discriminator'])
    genG_optimizer.load_state_dict(checkpoint['G_optimizer_state_dict'])
    discriM_optimizer.load_state_dict(checkpoint['D_optimizer_state_dict'])
    print(f"Checkpoint loaded from {model_path}")

# %%
filename="checkpoint.pth.tar"

load_model = load_checkpoint(os.path.join(checkpoint_dir, f"{filename}_{num_epochs}"), G, D, g_optimizer, d_optimizer)
# Out:
# Checkpoint loaded from ./training_checkpoints_mse/checkpoint.pth.tar_300

# %% [markdown]
# **Step 6: Re-train the GAN model to see if you can improve.**

# %%
# %%time

num_epochs = 50
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(301, 350):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [301/50], Step [200/600], d_loss: 0.4612, g_loss: 0.3943, D(x): 0.59, D(G(z)): 0.42
# Epoch [301/50], Step [400/600], d_loss: 0.4932, g_loss: 0.4272, D(x): 0.52, D(G(z)): 0.40
# Epoch [301/50], Step [600/600], d_loss: 0.3004, g_loss: 0.4755, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0302.png
# Epoch [302/50], Step [200/600], d_loss: 0.4344, g_loss: 0.3445, D(x): 0.59, D(G(z)): 0.42
# Epoch [302/50], Step [400/600], d_loss: 0.3506, g_loss: 0.4743, D(x): 0.62, D(G(z)): 0.33
# Epoch [302/50], Step [600/600], d_loss: 0.4689, g_loss: 0.3339, D(x): 0.58, D(G(z)): 0.42
# Saving fake_images-0303.png
# Epoch [303/50], Step [200/600], d_loss: 0.2990, g_loss: 0.5350, D(x): 0.63, D(G(z)): 0.29
# Epoch [303/50], Step [400/600], d_loss: 0.5169, g_loss: 0.4624, D(x): 0.54, D(G(z)): 0.44
# Epoch [303/50], Step [600/600], d_loss: 0.3752, g_loss: 0.4460, D(x): 0.63, D(G(z)): 0.36
# Saving fake_images-0304.png
# Epoch [304/50], Step [200/600], d_loss: 0.3754, g_loss: 0.4613, D(x): 0.66, D(G(z)): 0.38
# Epoch [304/50], Step [400/600], d_loss: 0.4898, g_loss: 0.3588, D(x): 0.53, D(G(z)): 0.41
# Epoch [304/50], Step [600/600], d_loss: 0.3225, g_loss: 0.5181, D(x): 0.64, D(G(z)): 0.32
# Saving fake_images-0305.png
# Epoch [305/50], Step [200/600], d_loss: 0.4703, g_loss: 0.3707, D(x): 0.59, D(G(z)): 0.44
# Epoch [305/50], Step [400/600], d_loss: 0.2499, g_loss: 0.5784, D(x): 0.72, D(G(z)): 0.30
# Epoch [305/50], Step [600/600], d_loss: 0.3965, g_loss: 0.4329, D(x): 0.63, D(G(z)): 0.40
# Saving fake_images-0306.png
# Epoch [306/50], Step [200/600], d_loss: 0.4048, g_loss: 0.4225, D(x): 0.65, D(G(z)): 0.42
# Epoch [306/50], Step [400/600], d_loss: 0.4468, g_loss: 0.3680, D(x): 0.59, D(G(z)): 0.44
# Epoch [306/50], Step [600/600], d_loss: 0.3794, g_loss: 0.4377, D(x): 0.69, D(G(z)): 0.44
# Saving fake_images-0307.png
# Epoch [307/50], Step [200/600], d_loss: 0.4302, g_loss: 0.4401, D(x): 0.58, D(G(z)): 0.40
# Epoch [307/50], Step [400/600], d_loss: 0.4756, g_loss: 0.3748, D(x): 0.56, D(G(z)): 0.40
# Epoch [307/50], Step [600/600], d_loss: 0.4256, g_loss: 0.4741, D(x): 0.55, D(G(z)): 0.34
# Saving fake_images-0308.png
# Epoch [308/50], Step [200/600], d_loss: 0.3982, g_loss: 0.5088, D(x): 0.57, D(G(z)): 0.34
# Epoch [308/50], Step [400/600], d_loss: 0.3774, g_loss: 0.4459, D(x): 0.62, D(G(z)): 0.37
# Epoch [308/50], Step [600/600], d_loss: 0.2884, g_loss: 0.4025, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0309.png
# Epoch [309/50], Step [200/600], d_loss: 0.3149, g_loss: 0.5034, D(x): 0.66, D(G(z)): 0.33
# Epoch [309/50], Step [400/600], d_loss: 0.3498, g_loss: 0.4455, D(x): 0.64, D(G(z)): 0.35
# Epoch [309/50], Step [600/600], d_loss: 0.4252, g_loss: 0.3480, D(x): 0.65, D(G(z)): 0.44
# Saving fake_images-0310.png
# Epoch [310/50], Step [200/600], d_loss: 0.3824, g_loss: 0.4649, D(x): 0.59, D(G(z)): 0.36
# Epoch [310/50], Step [400/600], d_loss: 0.4885, g_loss: 0.4294, D(x): 0.54, D(G(z)): 0.40
# Epoch [310/50], Step [600/600], d_loss: 0.3696, g_loss: 0.4884, D(x): 0.60, D(G(z)): 0.34
# Saving fake_images-0311.png
# Epoch [311/50], Step [200/600], d_loss: 0.4187, g_loss: 0.4375, D(x): 0.55, D(G(z)): 0.36
# Epoch [311/50], Step [400/600], d_loss: 0.2953, g_loss: 0.4652, D(x): 0.71, D(G(z)): 0.35
# Epoch [311/50], Step [600/600], d_loss: 0.3070, g_loss: 0.4752, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0312.png
# Epoch [312/50], Step [200/600], d_loss: 0.4101, g_loss: 0.4430, D(x): 0.62, D(G(z)): 0.40
# Epoch [312/50], Step [400/600], d_loss: 0.4160, g_loss: 0.4293, D(x): 0.62, D(G(z)): 0.43
# Epoch [312/50], Step [600/600], d_loss: 0.3684, g_loss: 0.5028, D(x): 0.64, D(G(z)): 0.37
# Saving fake_images-0313.png
# Epoch [313/50], Step [200/600], d_loss: 0.3962, g_loss: 0.4151, D(x): 0.66, D(G(z)): 0.43
# Epoch [313/50], Step [400/600], d_loss: 0.4218, g_loss: 0.4583, D(x): 0.60, D(G(z)): 0.40
# Epoch [313/50], Step [600/600], d_loss: 0.3261, g_loss: 0.4752, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0314.png
# Epoch [314/50], Step [200/600], d_loss: 0.3245, g_loss: 0.5203, D(x): 0.64, D(G(z)): 0.33
# Epoch [314/50], Step [400/600], d_loss: 0.4403, g_loss: 0.4514, D(x): 0.54, D(G(z)): 0.38
# Epoch [314/50], Step [600/600], d_loss: 0.2842, g_loss: 0.5025, D(x): 0.77, D(G(z)): 0.40
# Saving fake_images-0315.png
# Epoch [315/50], Step [200/600], d_loss: 0.4603, g_loss: 0.4422, D(x): 0.53, D(G(z)): 0.38
# Epoch [315/50], Step [400/600], d_loss: 0.3660, g_loss: 0.4787, D(x): 0.56, D(G(z)): 0.32
# Epoch [315/50], Step [600/600], d_loss: 0.3136, g_loss: 0.4742, D(x): 0.68, D(G(z)): 0.34
# Saving fake_images-0316.png
# Epoch [316/50], Step [200/600], d_loss: 0.5086, g_loss: 0.4084, D(x): 0.49, D(G(z)): 0.40
# Epoch [316/50], Step [400/600], d_loss: 0.3143, g_loss: 0.5194, D(x): 0.67, D(G(z)): 0.34
# Epoch [316/50], Step [600/600], d_loss: 0.3645, g_loss: 0.4669, D(x): 0.58, D(G(z)): 0.33
# Saving fake_images-0317.png
# Epoch [317/50], Step [200/600], d_loss: 0.4075, g_loss: 0.4761, D(x): 0.58, D(G(z)): 0.37
# Epoch [317/50], Step [400/600], d_loss: 0.5135, g_loss: 0.3362, D(x): 0.60, D(G(z)): 0.49
# Epoch [317/50], Step [600/600], d_loss: 0.3975, g_loss: 0.4554, D(x): 0.63, D(G(z)): 0.39
# Saving fake_images-0318.png
# Epoch [318/50], Step [200/600], d_loss: 0.5065, g_loss: 0.4081, D(x): 0.57, D(G(z)): 0.47
# Epoch [318/50], Step [400/600], d_loss: 0.3273, g_loss: 0.4811, D(x): 0.68, D(G(z)): 0.37
# Epoch [318/50], Step [600/600], d_loss: 0.3529, g_loss: 0.5224, D(x): 0.61, D(G(z)): 0.32
# Saving fake_images-0319.png
# Epoch [319/50], Step [200/600], d_loss: 0.3028, g_loss: 0.5474, D(x): 0.65, D(G(z)): 0.31
# Epoch [319/50], Step [400/600], d_loss: 0.5283, g_loss: 0.3629, D(x): 0.55, D(G(z)): 0.46
# Epoch [319/50], Step [600/600], d_loss: 0.2598, g_loss: 0.5835, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0320.png
# Epoch [320/50], Step [200/600], d_loss: 0.4124, g_loss: 0.4637, D(x): 0.58, D(G(z)): 0.36
# Epoch [320/50], Step [400/600], d_loss: 0.3313, g_loss: 0.5235, D(x): 0.67, D(G(z)): 0.37
# Epoch [320/50], Step [600/600], d_loss: 0.4638, g_loss: 0.4448, D(x): 0.52, D(G(z)): 0.38
# Saving fake_images-0321.png
# Epoch [321/50], Step [200/600], d_loss: 0.3127, g_loss: 0.5415, D(x): 0.61, D(G(z)): 0.26
# Epoch [321/50], Step [400/600], d_loss: 0.3465, g_loss: 0.4691, D(x): 0.67, D(G(z)): 0.37
# Epoch [321/50], Step [600/600], d_loss: 0.3705, g_loss: 0.4940, D(x): 0.61, D(G(z)): 0.36
# Saving fake_images-0322.png
# Epoch [322/50], Step [200/600], d_loss: 0.5159, g_loss: 0.4000, D(x): 0.56, D(G(z)): 0.46
# Epoch [322/50], Step [400/600], d_loss: 0.4691, g_loss: 0.3887, D(x): 0.63, D(G(z)): 0.45
# Epoch [322/50], Step [600/600], d_loss: 0.5115, g_loss: 0.3258, D(x): 0.54, D(G(z)): 0.44
# Saving fake_images-0323.png
# Epoch [323/50], Step [200/600], d_loss: 0.3201, g_loss: 0.5437, D(x): 0.63, D(G(z)): 0.30
# Epoch [323/50], Step [400/600], d_loss: 0.3018, g_loss: 0.5478, D(x): 0.64, D(G(z)): 0.30
# Epoch [323/50], Step [600/600], d_loss: 0.4599, g_loss: 0.4676, D(x): 0.53, D(G(z)): 0.38
# Saving fake_images-0324.png
# Epoch [324/50], Step [200/600], d_loss: 0.3735, g_loss: 0.5161, D(x): 0.61, D(G(z)): 0.36
# Epoch [324/50], Step [400/600], d_loss: 0.3690, g_loss: 0.4140, D(x): 0.64, D(G(z)): 0.37
# Epoch [324/50], Step [600/600], d_loss: 0.3232, g_loss: 0.5073, D(x): 0.70, D(G(z)): 0.38
# Saving fake_images-0325.png
# Epoch [325/50], Step [200/600], d_loss: 0.3066, g_loss: 0.4912, D(x): 0.66, D(G(z)): 0.32
# Epoch [325/50], Step [400/600], d_loss: 0.3820, g_loss: 0.4347, D(x): 0.65, D(G(z)): 0.39
# Epoch [325/50], Step [600/600], d_loss: 0.3228, g_loss: 0.4590, D(x): 0.69, D(G(z)): 0.39
# Saving fake_images-0326.png
# Epoch [326/50], Step [200/600], d_loss: 0.3198, g_loss: 0.4743, D(x): 0.62, D(G(z)): 0.31
# Epoch [326/50], Step [400/600], d_loss: 0.4157, g_loss: 0.4145, D(x): 0.61, D(G(z)): 0.39
# Epoch [326/50], Step [600/600], d_loss: 0.6376, g_loss: 0.3863, D(x): 0.46, D(G(z)): 0.48
# Saving fake_images-0327.png
# Epoch [327/50], Step [200/600], d_loss: 0.4301, g_loss: 0.4550, D(x): 0.58, D(G(z)): 0.39
# Epoch [327/50], Step [400/600], d_loss: 0.4618, g_loss: 0.4374, D(x): 0.55, D(G(z)): 0.39
# Epoch [327/50], Step [600/600], d_loss: 0.2943, g_loss: 0.5015, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0328.png
# Epoch [328/50], Step [200/600], d_loss: 0.2964, g_loss: 0.6095, D(x): 0.64, D(G(z)): 0.28
# Epoch [328/50], Step [400/600], d_loss: 0.4384, g_loss: 0.4254, D(x): 0.61, D(G(z)): 0.43
# Epoch [328/50], Step [600/600], d_loss: 0.5349, g_loss: 0.4379, D(x): 0.52, D(G(z)): 0.43
# Saving fake_images-0329.png
# Epoch [329/50], Step [200/600], d_loss: 0.3740, g_loss: 0.4325, D(x): 0.62, D(G(z)): 0.38
# Epoch [329/50], Step [400/600], d_loss: 0.3503, g_loss: 0.4634, D(x): 0.68, D(G(z)): 0.38
# Epoch [329/50], Step [600/600], d_loss: 0.4608, g_loss: 0.5161, D(x): 0.52, D(G(z)): 0.36
# Saving fake_images-0330.png
# Epoch [330/50], Step [200/600], d_loss: 0.4547, g_loss: 0.4371, D(x): 0.55, D(G(z)): 0.36
# Epoch [330/50], Step [400/600], d_loss: 0.5354, g_loss: 0.3815, D(x): 0.51, D(G(z)): 0.44
# Epoch [330/50], Step [600/600], d_loss: 0.3944, g_loss: 0.4220, D(x): 0.61, D(G(z)): 0.37
# Saving fake_images-0331.png
# Epoch [331/50], Step [200/600], d_loss: 0.3033, g_loss: 0.4940, D(x): 0.69, D(G(z)): 0.35
# Epoch [331/50], Step [400/600], d_loss: 0.5165, g_loss: 0.3750, D(x): 0.57, D(G(z)): 0.48
# Epoch [331/50], Step [600/600], d_loss: 0.5087, g_loss: 0.4665, D(x): 0.54, D(G(z)): 0.40
# Saving fake_images-0332.png
# Epoch [332/50], Step [200/600], d_loss: 0.3120, g_loss: 0.4425, D(x): 0.68, D(G(z)): 0.33
# Epoch [332/50], Step [400/600], d_loss: 0.4016, g_loss: 0.3535, D(x): 0.64, D(G(z)): 0.42
# Epoch [332/50], Step [600/600], d_loss: 0.3529, g_loss: 0.3409, D(x): 0.67, D(G(z)): 0.39
# Saving fake_images-0333.png
# Epoch [333/50], Step [200/600], d_loss: 0.4537, g_loss: 0.3208, D(x): 0.60, D(G(z)): 0.44
# Epoch [333/50], Step [400/600], d_loss: 0.3732, g_loss: 0.5128, D(x): 0.63, D(G(z)): 0.37
# Epoch [333/50], Step [600/600], d_loss: 0.2438, g_loss: 0.5334, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0334.png
# Epoch [334/50], Step [200/600], d_loss: 0.4408, g_loss: 0.4195, D(x): 0.58, D(G(z)): 0.40
# Epoch [334/50], Step [400/600], d_loss: 0.5392, g_loss: 0.3317, D(x): 0.54, D(G(z)): 0.45
# Epoch [334/50], Step [600/600], d_loss: 0.3237, g_loss: 0.5176, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0335.png
# Epoch [335/50], Step [200/600], d_loss: 0.2561, g_loss: 0.4976, D(x): 0.74, D(G(z)): 0.34
# Epoch [335/50], Step [400/600], d_loss: 0.4437, g_loss: 0.4526, D(x): 0.62, D(G(z)): 0.45
# Epoch [335/50], Step [600/600], d_loss: 0.4612, g_loss: 0.4178, D(x): 0.57, D(G(z)): 0.40
# Saving fake_images-0336.png
# Epoch [336/50], Step [200/600], d_loss: 0.4080, g_loss: 0.4880, D(x): 0.61, D(G(z)): 0.38
# Epoch [336/50], Step [400/600], d_loss: 0.3320, g_loss: 0.4697, D(x): 0.65, D(G(z)): 0.35
# Epoch [336/50], Step [600/600], d_loss: 0.3495, g_loss: 0.4930, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0337.png
# Epoch [337/50], Step [200/600], d_loss: 0.6110, g_loss: 0.3547, D(x): 0.51, D(G(z)): 0.51
# Epoch [337/50], Step [400/600], d_loss: 0.3179, g_loss: 0.4275, D(x): 0.69, D(G(z)): 0.38
# Epoch [337/50], Step [600/600], d_loss: 0.2587, g_loss: 0.5166, D(x): 0.75, D(G(z)): 0.34
# Saving fake_images-0338.png
# Epoch [338/50], Step [200/600], d_loss: 0.4586, g_loss: 0.3945, D(x): 0.55, D(G(z)): 0.39
# Epoch [338/50], Step [400/600], d_loss: 0.3892, g_loss: 0.3968, D(x): 0.65, D(G(z)): 0.43
# Epoch [338/50], Step [600/600], d_loss: 0.2786, g_loss: 0.5274, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0339.png
# Epoch [339/50], Step [200/600], d_loss: 0.4881, g_loss: 0.3842, D(x): 0.56, D(G(z)): 0.40
# Epoch [339/50], Step [400/600], d_loss: 0.5190, g_loss: 0.4088, D(x): 0.49, D(G(z)): 0.38
# Epoch [339/50], Step [600/600], d_loss: 0.4555, g_loss: 0.3802, D(x): 0.63, D(G(z)): 0.47
# Saving fake_images-0340.png
# Epoch [340/50], Step [200/600], d_loss: 0.3245, g_loss: 0.4819, D(x): 0.69, D(G(z)): 0.37
# Epoch [340/50], Step [400/600], d_loss: 0.2402, g_loss: 0.5197, D(x): 0.70, D(G(z)): 0.28
# Epoch [340/50], Step [600/600], d_loss: 0.4069, g_loss: 0.4568, D(x): 0.62, D(G(z)): 0.40
# Saving fake_images-0341.png
# Epoch [341/50], Step [200/600], d_loss: 0.4264, g_loss: 0.4124, D(x): 0.59, D(G(z)): 0.39
# Epoch [341/50], Step [400/600], d_loss: 0.3558, g_loss: 0.4138, D(x): 0.65, D(G(z)): 0.37
# Epoch [341/50], Step [600/600], d_loss: 0.3643, g_loss: 0.4680, D(x): 0.64, D(G(z)): 0.38
# Saving fake_images-0342.png
# Epoch [342/50], Step [200/600], d_loss: 0.3565, g_loss: 0.4457, D(x): 0.64, D(G(z)): 0.35
# Epoch [342/50], Step [400/600], d_loss: 0.3769, g_loss: 0.3669, D(x): 0.61, D(G(z)): 0.37
# Epoch [342/50], Step [600/600], d_loss: 0.4306, g_loss: 0.4525, D(x): 0.61, D(G(z)): 0.41
# Saving fake_images-0343.png
# Epoch [343/50], Step [200/600], d_loss: 0.2420, g_loss: 0.5176, D(x): 0.72, D(G(z)): 0.31
# Epoch [343/50], Step [400/600], d_loss: 0.3552, g_loss: 0.4946, D(x): 0.62, D(G(z)): 0.34
# Epoch [343/50], Step [600/600], d_loss: 0.4436, g_loss: 0.3983, D(x): 0.57, D(G(z)): 0.40
# Saving fake_images-0344.png
# Epoch [344/50], Step [200/600], d_loss: 0.3180, g_loss: 0.4423, D(x): 0.65, D(G(z)): 0.35
# Epoch [344/50], Step [400/600], d_loss: 0.3350, g_loss: 0.4916, D(x): 0.65, D(G(z)): 0.35
# Epoch [344/50], Step [600/600], d_loss: 0.3812, g_loss: 0.4228, D(x): 0.63, D(G(z)): 0.40
# Saving fake_images-0345.png
# Epoch [345/50], Step [200/600], d_loss: 0.3297, g_loss: 0.5224, D(x): 0.62, D(G(z)): 0.32
# Epoch [345/50], Step [400/600], d_loss: 0.3747, g_loss: 0.4516, D(x): 0.65, D(G(z)): 0.39
# Epoch [345/50], Step [600/600], d_loss: 0.2815, g_loss: 0.6010, D(x): 0.64, D(G(z)): 0.26
# Saving fake_images-0346.png
# Epoch [346/50], Step [200/600], d_loss: 0.4151, g_loss: 0.3941, D(x): 0.57, D(G(z)): 0.37
# Epoch [346/50], Step [400/600], d_loss: 0.4861, g_loss: 0.4380, D(x): 0.53, D(G(z)): 0.39
# Epoch [346/50], Step [600/600], d_loss: 0.3087, g_loss: 0.5871, D(x): 0.61, D(G(z)): 0.26
# Saving fake_images-0347.png
# Epoch [347/50], Step [200/600], d_loss: 0.3322, g_loss: 0.5161, D(x): 0.64, D(G(z)): 0.32
# Epoch [347/50], Step [400/600], d_loss: 0.4524, g_loss: 0.4354, D(x): 0.58, D(G(z)): 0.42
# Epoch [347/50], Step [600/600], d_loss: 0.4186, g_loss: 0.4752, D(x): 0.52, D(G(z)): 0.31
# Saving fake_images-0348.png
# Epoch [348/50], Step [200/600], d_loss: 0.3345, g_loss: 0.5080, D(x): 0.65, D(G(z)): 0.34
# Epoch [348/50], Step [400/600], d_loss: 0.4176, g_loss: 0.4809, D(x): 0.59, D(G(z)): 0.40
# Epoch [348/50], Step [600/600], d_loss: 0.2801, g_loss: 0.4829, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0349.png
# Epoch [349/50], Step [200/600], d_loss: 0.2731, g_loss: 0.5211, D(x): 0.73, D(G(z)): 0.35
# Epoch [349/50], Step [400/600], d_loss: 0.4532, g_loss: 0.3895, D(x): 0.61, D(G(z)): 0.42
# Epoch [349/50], Step [600/600], d_loss: 0.4080, g_loss: 0.5002, D(x): 0.62, D(G(z)): 0.38
# Saving fake_images-0350.png
# CPU times: user 23min 7s, sys: 6.67 s, total: 23min 14s
# Wall time: 23min 27s

# %%
Image('./samples_chk/fake_images-0300.png')

# %%
Image('./samples_chk/fake_images-0350.png')

# %%
# Show plot of real and fake scores

plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# **Step 7: Save the model weights without using checkpoints.**

# %%
# specify a path to save models

save_directory = './saved_models_mse'

# Check if the directory exists, and if not, create it
if not os.path.exists(save_directory):
    os.makedirs(save_directory)

# Save weights without check point
torch.save(G.state_dict, os.path.join(save_directory, 'G_weights.pth'))
torch.save(D.state_dict, os.path.join(save_directory, 'D_weights.pth'))

# %% [markdown]
# **Step 8: Load the model weights without using checkpoints.**

# %%
# Load the models again

genG = G.to(device)
discriM = D.to(device)

# Load generator and discriminator weights
genG_weights = torch.load(os.path.join(save_directory, 'G_weights.pth'))
discriM_weights = torch.load(os.path.join(save_directory, 'D_weights.pth'))

# %% [markdown]
# ## Compare LS-GAN with GAN results

# %% [markdown]
# The comparison between GAN and LS-GAN:
#
# 1. GAN uses the binary cross entroy. LS-GAN uses the MSE.
# 2. On plotting the "Loss" graph, the LS-GAN start to overlap near around 250 epochs, while GAN is almost near around 400 epochs.
# 3. The real and fake scores start to barely get close near 650 epochs, while LS-GAN is around near 400 epochs.
# 4. GAN and LS-GAN took the same amount of time, around 3 hours for 300 epochs.
# 5. The images generated by GAN appear to be smoother than those by LS_GAN.
# 6. GANs require careful tuning and monitoring during training to ensure stability. On the other hand, LS-GANs are considered to be more stable during training and appear to converge faster.
